# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install koreanize-matplotlib

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import os

if os.name == 'posix':
    plt.rc("font", family="AppleGothic")
else:
    plt.rc("font", family="Malgun Gothic")
plt.rc("axes", unicode_minus=False)

import koreanize_matplotlib
# %config InlineBackend.figure_format = 'retina'

# 경고 무시
import warnings
warnings.filterwarnings('ignore')

# row 생략 없이 출력
pd.set_option('display.max_rows', None)
# col 생략 없이 출력
pd.set_option('display.max_columns', None)

# %%
data = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/여성가족부_청소년매체이용및유해환경실태조사(총괄)_2022.csv', encoding ='CP949')

# %% [markdown]
# # 1. 예방교육 데이터
#   ## 1)  예방교육 경험여부 및 도움정도 설문 컬럼 (7개 예방교육)
# ```
# 29(경험여부). 약물 이용 교육 경험 및 도움 정도 - 1) 음주 예방 교육
# 29(경험여부). 약물 이용 교육 경험 및 도움 정도 - 2) 흡연 예방 교육
# 29-1(도움정도). 약물 이용 교육 경험 및 도움 정도 - 1) 음주 예방 교육
# 29-1(도움정도). 약물 이용 교육 경험 및 도움 정도 - 2) 흡연 예방 교육
# 16(경험여부). 학교 폭력 및 성폭력 예방 교육 경험 및 도움 정도 - 1) 학교폭력 예방 교육
# 16(경험여부). 학교 폭력 및 성폭력 예방 교육 경험 및 도움 정도 - 2) 성폭력 예방 교육
# 16(경험여부). 학교 폭력 및 성폭력 예방 교육 경험 및 도움 정도 - 3) 디지털 성범죄 예방 교육
# 16(경험여부). 학교 폭력 및 성폭력 예방 교육 경험 및 도움 정도 - 4) 성교육
# 16(경험여부). 학교 폭력 및 성폭력 예방 교육 경험 및 도움 정도 - 5) 성매매 예방 교육
# 16-1(도움정도). 학교 폭력 및 성폭력 예방 교육 경험 및 도움 정도 - 1) 학교폭력 예방 교육
# 16-1(도움정도). 학교 폭력 및 성폭력 예방 교육 경험 및 도움 정도 - 2) 성폭력 예방 교육
# 16-1(도움정도). 학교 폭력 및 성폭력 예방 교육 경험 및 도움 정도 - 3) 디지털 성범죄 예방 교육
# 16-1(도움정도). 학교 폭력 및 성폭력 예방 교육 경험 및 도움 정도 - 4) 성교육
# 16-1(도움정도). 학교 폭력 및 성폭력 예방 교육 경험 및 도움 정도 - 5) 성매매 예방 교육
# 9(경험여부). 매체 이용 교육 경험 및 도움 정도 - 1) 19세 이상 이용 가능한 영화, 게임, 동영상, 잡지, 사진 등으로 인한 피해 예방 교육
# 9(경험여부). 매체 이용 교육 경험 및 도움 정도 - 2) 온라인 도박으로 인한 피해 예방 교육
# 9(경험여부). 매체 이용 교육 경험 및 도움 정도 - 3) 건전한 인터넷/스마트폰 이용 교육
# 9(경험여부). 매체 이용 교육 경험 및 도움 정도 - 4) SNS 등 이용 시 개인정보보호 관련 교육
# 9-1(도움정도). 매체 이용 교육 경험 및 도움 정도 - 1) 19세 이상 이용 가능한 영화, 게임, 동영상, 잡지, 사진 등으로 인한 피해 예방 교육
# 9-1(도움정도). 매체 이용 교육 경험 및 도움 정도 - 2) 온라인 도박으로 인한 피해 예방 교육
# 9-1(도움정도). 매체 이용 교육 경험 및 도움 정도 - 3) 건전한 인터넷/스마트폰 이용 교육
# 9-1(도움정도). 매체 이용 교육 경험 및 도움 정도 - 4) SNS 등 이용 시 개인정보보호 관련 교육
# ```
# ## 2) 컬럼 리네임
# * (경험여부) 컬럼 규칙
#   * E_{i}
#   * 1: 음주 예방 교육
#   * 2: 흡연 예방 교육
#   * 3: 학교폭력 예방 교육
#   * 4: 성폭력 예방 교육
#   * 5: 디지털 성범죄 예방교육
#   * 6: 성교육
#   * 7: 성매매 예방교육
#   * 8: 성인매체 피해 예방교육
#   * 9: 온라인 도박 피햬 예방교육
#   * 10: 인터넷/스마트폰 이용교육
#   * 11: 개인정보보호 교육
#
# * (도움정도) 컬럼 규칙
#   * H_{i}
#   * 1: 음주 예방 교육
#   * 2: 흡연 예방 교육
#   * 3: 학교폭력 예방 교육
#   * 4: 성폭력 예방 교육
#   * 5: 디지털 성범죄 예방교육
#   * 6: 성교육
#   * 7: 성매매 예방교육
#   * 8: 성인매체 피해 예방교육
#   * 9: 온라인 도박 피햬 예방교육
#   * 10: 인터넷/스마트폰 이용교육
#   * 11: 개인정보보호 교육
#
#
# ```

# %%
df = data[[
    '지역별',
    '학교급',
    '29(경험여부). 약물 이용 교육 경험 및 도움 정도 - 1) 음주 예방 교육',
    '29(경험여부). 약물 이용 교육 경험 및 도움 정도 - 2) 흡연 예방 교육',
    '16(경험여부). 학교 폭력 및 성폭력 예방 교육 경험 및 도움 정도 - 1) 학교폭력 예방 교육',
    '16(경험여부). 학교 폭력 및 성폭력 예방 교육 경험 및 도움 정도 - 2) 성폭력 예방 교육',
    '16(경험여부). 학교 폭력 및 성폭력 예방 교육 경험 및 도움 정도 - 3) 디지털 성범죄 예방 교육',
    '16(경험여부). 학교 폭력 및 성폭력 예방 교육 경험 및 도움 정도 - 4) 성교육',
    '16(경험여부). 학교 폭력 및 성폭력 예방 교육 경험 및 도움 정도 - 5) 성매매 예방 교육',
    '29-1(도움정도). 약물 이용 교육 경험 및 도움 정도 - 1) 음주 예방 교육',
    '29-1(도움정도). 약물 이용 교육 경험 및 도움 정도 - 2) 흡연 예방 교육',
    '16-1(도움정도). 학교 폭력 및 성폭력 예방 교육 경험 및 도움 정도 - 1) 학교폭력 예방 교육',
    '16-1(도움정도). 학교 폭력 및 성폭력 예방 교육 경험 및 도움 정도 - 2) 성폭력 예방 교육',
    '16-1(도움정도). 학교 폭력 및 성폭력 예방 교육 경험 및 도움 정도 - 3) 디지털 성범죄 예방 교육',
    '16-1(도움정도). 학교 폭력 및 성폭력 예방 교육 경험 및 도움 정도 - 4) 성교육',
    '16-1(도움정도). 학교 폭력 및 성폭력 예방 교육 경험 및 도움 정도 - 5) 성매매 예방 교육',
    '9(경험여부). 매체 이용 교육 경험 및 도움 정도 - 1) 19세 이상 이용 가능한 영화, 게임, 동영상, 잡지, 사진 등으로 인한 피해 예방 교육',
    '9(경험여부). 매체 이용 교육 경험 및 도움 정도 - 2) 온라인 도박으로 인한 피해 예방 교육',
    '9(경험여부). 매체 이용 교육 경험 및 도움 정도 - 3) 건전한 인터넷/스마트폰 이용 교육',
    '9(경험여부). 매체 이용 교육 경험 및 도움 정도 - 4) SNS 등 이용 시 개인정보보호 관련 교육',
    '9-1(도움정도). 매체 이용 교육 경험 및 도움 정도 - 1) 19세 이상 이용 가능한 영화, 게임, 동영상, 잡지, 사진 등으로 인한 피해 예방 교육',
    '9-1(도움정도). 매체 이용 교육 경험 및 도움 정도 - 2) 온라인 도박으로 인한 피해 예방 교육',
    '9-1(도움정도). 매체 이용 교육 경험 및 도움 정도 - 3) 건전한 인터넷/스마트폰 이용 교육',
    '9-1(도움정도). 매체 이용 교육 경험 및 도움 정도 - 4) SNS 등 이용 시 개인정보보호 관련 교육'
]]

# %%
#컬럼 리네임
df.rename(columns={
    '지역별':'시도',
    '29(경험여부). 약물 이용 교육 경험 및 도움 정도 - 1) 음주 예방 교육': 'E_1',
    '29(경험여부). 약물 이용 교육 경험 및 도움 정도 - 2) 흡연 예방 교육': 'E_2',
    '16(경험여부). 학교 폭력 및 성폭력 예방 교육 경험 및 도움 정도 - 1) 학교폭력 예방 교육': 'E_3',
    '16(경험여부). 학교 폭력 및 성폭력 예방 교육 경험 및 도움 정도 - 2) 성폭력 예방 교육': 'E_4',
    '16(경험여부). 학교 폭력 및 성폭력 예방 교육 경험 및 도움 정도 - 3) 디지털 성범죄 예방 교육': 'E_5',
    '16(경험여부). 학교 폭력 및 성폭력 예방 교육 경험 및 도움 정도 - 4) 성교육': 'E_6',
    '16(경험여부). 학교 폭력 및 성폭력 예방 교육 경험 및 도움 정도 - 5) 성매매 예방 교육': 'E_7',
    '9(경험여부). 매체 이용 교육 경험 및 도움 정도 - 1) 19세 이상 이용 가능한 영화, 게임, 동영상, 잡지, 사진 등으로 인한 피해 예방 교육' : 'E_8' ,
    '9(경험여부). 매체 이용 교육 경험 및 도움 정도 - 2) 온라인 도박으로 인한 피해 예방 교육': 'E_9',
    '9(경험여부). 매체 이용 교육 경험 및 도움 정도 - 3) 건전한 인터넷/스마트폰 이용 교육': 'E_10',
    '9(경험여부). 매체 이용 교육 경험 및 도움 정도 - 4) SNS 등 이용 시 개인정보보호 관련 교육': 'E_11',
    '29-1(도움정도). 약물 이용 교육 경험 및 도움 정도 - 1) 음주 예방 교육': 'A_1',
    '29-1(도움정도). 약물 이용 교육 경험 및 도움 정도 - 2) 흡연 예방 교육': 'A_2',
    '16-1(도움정도). 학교 폭력 및 성폭력 예방 교육 경험 및 도움 정도 - 1) 학교폭력 예방 교육': 'A_3',
    '16-1(도움정도). 학교 폭력 및 성폭력 예방 교육 경험 및 도움 정도 - 2) 성폭력 예방 교육': 'A_4',
    '16-1(도움정도). 학교 폭력 및 성폭력 예방 교육 경험 및 도움 정도 - 3) 디지털 성범죄 예방 교육': 'A_5',
    '16-1(도움정도). 학교 폭력 및 성폭력 예방 교육 경험 및 도움 정도 - 4) 성교육': 'A_6',
    '16-1(도움정도). 학교 폭력 및 성폭력 예방 교육 경험 및 도움 정도 - 5) 성매매 예방 교육': 'A_7',
    '9-1(도움정도). 매체 이용 교육 경험 및 도움 정도 - 1) 19세 이상 이용 가능한 영화, 게임, 동영상, 잡지, 사진 등으로 인한 피해 예방 교육':'A_8',
    '9-1(도움정도). 매체 이용 교육 경험 및 도움 정도 - 2) 온라인 도박으로 인한 피해 예방 교육':'A_9',
    '9-1(도움정도). 매체 이용 교육 경험 및 도움 정도 - 3) 건전한 인터넷/스마트폰 이용 교육':'A_10',
    '9-1(도움정도). 매체 이용 교육 경험 및 도움 정도 - 4) SNS 등 이용 시 개인정보보호 관련 교육':'A_11'
    }, inplace=True)

# %%
df.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17140 entries, 0 to 17139
# Data columns (total 24 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   시도      17140 non-null  int64
#  1   학교급     17140 non-null  int64
#  2   E_1     11891 non-null  float64
#  3   E_2     11891 non-null  float64
#  4   E_3     17140 non-null  int64
#  5   E_4     17140 non-null  int64
#  6   E_5     17140 non-null  int64
#  7   E_6     17140 non-null  int64
#  8   E_7     11891 non-null  float64
#  9   A_1     7220 non-null   float64
#  10  A_2     10341 non-null  float64
#  11  A_3     16382 non-null  float64
#  12  A_4     15631 non-null  float64
#  13  A_5     14842 non-null  float64
#  14  A_6     14491 non-null  float64
#  15  A_7     8176 non-null   float64
#  16  E_8     17140 non-null  int64
#  17  E_9     17140 non-null  int64
#  18  E_10    17140 non-null  int64
#  19  E_11    17140 non-null  int64
#  20  A_8     9887 non-null   float64
# ...

# %%
# null값 확인
df.isnull().sum()
# Out:
# 시도         0
# 학교급        0
# E_1     5249
# E_2     5249
# E_3        0
# E_4        0
# E_5        0
# E_6        0
# E_7     5249
# A_1     9920
# A_2     6799
# A_3      758
# A_4     1509
# A_5     2298
# A_6     2649
# A_7     8964
# E_8        0
# E_9        0
# E_10       0
# E_11       0
# A_8     7253
# A_9     7291
# A_10    3507
# A_11    5533
# dtype: int64

# %%
df.sample(5)
# Out:
#        시도  학교급  E_1  E_2  E_3  E_4  E_5  E_6  E_7  A_1  A_2  A_3  A_4  A_5  \
# 4620    6    1  NaN  NaN    1    1    1    1  NaN  NaN  NaN  4.0  4.0  4.0
# 9107   10    2  1.0  1.0    1    1    1    1  1.0  3.0  3.0  3.0  3.0  3.0
# 14303  17    3  1.0  1.0    1    1    1    1  1.0  3.0  3.0  3.0  3.0  3.0
# 16090   9    3  2.0  1.0    1    1    1    1  2.0  NaN  3.0  3.0  3.0  4.0
# 8561    9    3  1.0  1.0    1    1    1    1  1.0  3.0  3.0  3.0  3.0  3.0
#
#        A_6  A_7  E_8  E_9  E_10  E_11  A_8  A_9  A_10  A_11
# 4620   4.0  NaN    2    2     2     2  NaN  NaN   NaN   NaN
# 9107   1.0  3.0    1    1     2     1  2.0  3.0   NaN   3.0
# 14303  3.0  3.0    2    1     1     1  NaN  3.0   3.0   3.0
# 16090  3.0  NaN    1    1     1     1  3.0  4.0   3.0   3.0
# 8561   3.0  3.0    1    1     1     1  3.0  3.0   3.0   3.0

# %% [markdown]
# # 2. 지역명 변경

# %%
# 지역별 숫자와 지역명을 매칭하는 딕셔너리 생성
region_mapping = {
    1: '서울',
    2: '부산',
    3: '대구',
    4: '인천',
    5: '광주',
    6: '대전',
    7: '울산',
    8: '세종',
    9: '경기',
    10: '강원',
    11: '충북',
    12: '충남',
    13: '전북',
    14: '전남',
    15: '경북',
    16: '경남',
    17: '제주'
}

# %%
# 지역명 변경
df['시도'] = df['시도'].map(region_mapping)

# %%
df['시도'].value_counts()
# Out:
# 시도
# 경기    2980
# 서울    2027
# 경남    1044
# 인천    1031
# 부산     981
# 경북     890
# 충남     863
# 대구     816
# 전북     768
# 대전     754
# 울산     753
# 충북     752
# 전남     747
# 광주     725
# 제주     698
# 강원     695
# 세종     616
# Name: count, dtype: int64

# %% [markdown]
# # 3. 학교급 변경
#
# * 1 : 초등학교
# * 2 : 중학교
# * 3: 고등학교

# %%
df['학교급'].value_counts()
# Out:
# 학교급
# 3    6401
# 2    5490
# 1    5249
# Name: count, dtype: int64

# %%
# 지역별 숫자와 지역명을 매칭하는 딕셔너리 생성
degree_mapping = {
    1: '초등학교',
    2: '중학교',
    3: '고등학교'
}

# %%
# 학교급 변경
df['학교급'] = df['학교급'].map(degree_mapping)

# 초등학교 제외
df= df[df['학교급'] !='초등학교']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 11891 entries, 457 to 17139
# Data columns (total 24 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   시도      11891 non-null  object
#  1   학교급     11891 non-null  object
#  2   E_1     11891 non-null  float64
#  3   E_2     11891 non-null  float64
#  4   E_3     11891 non-null  int64
#  5   E_4     11891 non-null  int64
#  6   E_5     11891 non-null  int64
#  7   E_6     11891 non-null  int64
#  8   E_7     11891 non-null  float64
#  9   A_1     7220 non-null   float64
#  10  A_2     10341 non-null  float64
#  11  A_3     11243 non-null  float64
#  12  A_4     10877 non-null  float64
#  13  A_5     10449 non-null  float64
#  14  A_6     10118 non-null  float64
#  15  A_7     8176 non-null   float64
#  16  E_8     11891 non-null  int64
#  17  E_9     11891 non-null  int64
#  18  E_10    11891 non-null  int64
#  19  E_11    11891 non-null  int64
#  20  A_8     6848 non-null   float64
# ...

# %%
df['E_7'].value_counts()
# Out:
# E_7
# 1.0    8121
# 2.0    3715
# 9.0      55
# Name: count, dtype: int64

# %% [markdown]
# # 4. 응답
# 응답 양식 모두 동일
#
# 예시
# ```
# * 9(경험여부). 매체 이용 교육 경험 및 도움 정도 - 1) 19세 이상 이용 가능한 영화, 게임, 동영상, 잡지, 사진 등으로 인한 피해 예방 교육
# => 음란물_예방
#
#   * 1 : 있다
#   * 2 : 없다
#   * 9 : 모름/무응답
#
# * 9-1(도움정도). 매체 이용 교육 경험 및 도움 정도 - 1) 19세 이상 이용 가능한 영화, 게임, 동영상, 잡지, 사진 등으로 인한 피해 예방 교육
# => 음란물_도움
#   * 1 : 전혀 도움이 안됨
#   * 2 : 별로 도움이 안됨
#   * 3 : 약간 도움이 됨
#   * 4 : 매우 도움이 됨
#   * 9 : 모름/무응답
#
# ```

# %% [markdown]
# ## 1) 예방교육 문항 응답자

# %%
# 예방교육 경험 여부 문항 df
edu_exp = df[[
    '시도',
    '학교급',
    'E_1',
    'E_2',
    'E_3',
    'E_4',
    'E_5',
    'E_6',
    'E_7',
    'E_8',
    'E_9',
    'E_10',
    'E_11'

]]

# (9)응답자 (2)으로 분류
edu_exp['E_1'] = edu_exp['E_1'].replace({9:2})
edu_exp['E_2'] = edu_exp['E_2'].replace({9:2})
edu_exp['E_3'] = edu_exp['E_3'].replace({9:2})
edu_exp['E_4'] = edu_exp['E_4'].replace({9:2})
edu_exp['E_5'] = edu_exp['E_5'].replace({9:2})
edu_exp['E_6'] = edu_exp['E_6'].replace({9:2})
edu_exp['E_7'] = edu_exp['E_7'].replace({9:2})
edu_exp['E_8'] = edu_exp['E_8'].replace({9:2})
edu_exp['E_9'] = edu_exp['E_9'].replace({9:2})
edu_exp['E_10'] = edu_exp['E_10'].replace({9:2})
edu_exp['E_11'] = edu_exp['E_11'].replace({9:2})

# %%
#교육별 분류
edu_exp_1 = edu_exp[['시도','학교급','E_1']] #음주 예방 교육
edu_exp_2 = edu_exp[['시도','학교급','E_2']] #흡연 예방 교육
edu_exp_3 = edu_exp[['시도','학교급','E_3']] #학교폭력 예방 교육
edu_exp_4 = edu_exp[['시도','학교급','E_4']] #성폭력 예방 교육
edu_exp_5 = edu_exp[['시도','학교급','E_5']] #디지털 성범죄 예방 교육
edu_exp_6 = edu_exp[['시도','학교급','E_6']] #성교육
edu_exp_7 = edu_exp[['시도','학교급','E_7']] #성매매 예방 교육
edu_exp_8 = edu_exp[['시도','학교급','E_8']] #성인매체 피해 예방교육
edu_exp_9 = edu_exp[['시도','학교급','E_9']] #온라인 도박 피햬 예방교육
edu_exp_10 = edu_exp[['시도','학교급','E_10']] #인터넷/스마트폰 이용교육
edu_exp_11 = edu_exp[['시도','학교급','E_11']] #개인정보보호 교육

# %%
# '시도'와 '학교급'별로 예방 교육에 대한 응답자 수
edu_exp_1_df = edu_exp_1.groupby(['시도', '학교급']).size().unstack(fill_value=0)
edu_exp_2_df = edu_exp_2.groupby(['시도', '학교급']).size().unstack(fill_value=0)
edu_exp_3_df = edu_exp_3.groupby(['시도', '학교급']).size().unstack(fill_value=0)
edu_exp_4_df = edu_exp_4.groupby(['시도', '학교급']).size().unstack(fill_value=0)
edu_exp_5_df = edu_exp_5.groupby(['시도', '학교급']).size().unstack(fill_value=0)
edu_exp_6_df = edu_exp_6.groupby(['시도', '학교급']).size().unstack(fill_value=0)
edu_exp_7_df = edu_exp_7.groupby(['시도', '학교급']).size().unstack(fill_value=0)
edu_exp_8_df = edu_exp_8.groupby(['시도', '학교급']).size().unstack(fill_value=0)
edu_exp_9_df = edu_exp_9.groupby(['시도', '학교급']).size().unstack(fill_value=0)
edu_exp_10_df = edu_exp_10.groupby(['시도', '학교급']).size().unstack(fill_value=0)
edu_exp_11_df = edu_exp_11.groupby(['시도', '학교급']).size().unstack(fill_value=0)

# %%
# 전체응답자 수
response_counts1 = edu_exp_1_df.sum(axis=1).reset_index(name='응답')
response_counts2 = edu_exp_2_df.sum(axis=1).reset_index(name='응답')
response_counts3 = edu_exp_3_df.sum(axis=1).reset_index(name='응답')
response_counts4 = edu_exp_4_df.sum(axis=1).reset_index(name='응답')
response_counts5 = edu_exp_5_df.sum(axis=1).reset_index(name='응답')
response_counts6 = edu_exp_6_df.sum(axis=1).reset_index(name='응답')
response_counts7 = edu_exp_7_df.sum(axis=1).reset_index(name='응답')
response_counts8 = edu_exp_8_df.sum(axis=1).reset_index(name='응답')
response_counts9 = edu_exp_9_df.sum(axis=1).reset_index(name='응답')
response_counts10 = edu_exp_10_df.sum(axis=1).reset_index(name='응답')
response_counts11 = edu_exp_11_df.sum(axis=1).reset_index(name='응답')

# %%
# 기존 데이터프레임과 새로운 데이터프레임 병합
edu_exp_1_df['응답'] = response_counts1['응답']
edu_exp_2_df['응답'] = response_counts2['응답']
edu_exp_3_df['응답'] = response_counts3['응답']
edu_exp_4_df['응답'] = response_counts4['응답']
edu_exp_5_df['응답'] = response_counts5['응답']
edu_exp_6_df['응답'] = response_counts6['응답']
edu_exp_7_df['응답'] = response_counts7['응답']
edu_exp_8_df['응답'] = response_counts8['응답']
edu_exp_9_df['응답'] = response_counts9['응답']
edu_exp_10_df['응답'] = response_counts10['응답']
edu_exp_11_df['응답'] = response_counts11['응답']

# %%
# '시도'와 '학교급'별로 예방 교육에 대한 응답자 수
edu_exp_1_df = edu_exp_1.groupby(['시도', '학교급']).size().unstack(fill_value=0)
edu_exp_2_df = edu_exp_2.groupby(['시도', '학교급']).size().unstack(fill_value=0)
edu_exp_3_df = edu_exp_3.groupby(['시도', '학교급']).size().unstack(fill_value=0)
edu_exp_4_df = edu_exp_4.groupby(['시도', '학교급']).size().unstack(fill_value=0)
edu_exp_5_df = edu_exp_5.groupby(['시도', '학교급']).size().unstack(fill_value=0)
edu_exp_6_df = edu_exp_6.groupby(['시도', '학교급']).size().unstack(fill_value=0)
edu_exp_7_df = edu_exp_7.groupby(['시도', '학교급']).size().unstack(fill_value=0)
edu_exp_8_df = edu_exp_8.groupby(['시도', '학교급']).size().unstack(fill_value=0)
edu_exp_9_df = edu_exp_9.groupby(['시도', '학교급']).size().unstack(fill_value=0)
edu_exp_10_df = edu_exp_10.groupby(['시도', '학교급']).size().unstack(fill_value=0)
edu_exp_11_df = edu_exp_11.groupby(['시도', '학교급']).size().unstack(fill_value=0)

# '고등학교'열 추가
edu_exp_1_df ['고등학교'] =edu_exp_1_df ['고등학교']
edu_exp_2_df ['고등학교'] =edu_exp_2_df ['고등학교']
edu_exp_3_df ['고등학교'] =edu_exp_3_df ['고등학교']
edu_exp_4_df ['고등학교'] =edu_exp_4_df ['고등학교']
edu_exp_5_df ['고등학교'] =edu_exp_5_df ['고등학교']
edu_exp_6_df ['고등학교'] =edu_exp_6_df ['고등학교']
edu_exp_7_df ['고등학교'] =edu_exp_7_df ['고등학교']
edu_exp_8_df ['고등학교'] =edu_exp_8_df ['고등학교']
edu_exp_9_df ['고등학교'] =edu_exp_9_df ['고등학교']
edu_exp_10_df ['고등학교'] =edu_exp_10_df ['고등학교']
edu_exp_11_df ['고등학교'] =edu_exp_11_df ['고등학교']

# '중학교'열 추가
edu_exp_1_df ['중학교'] =edu_exp_1_df ['중학교']
edu_exp_2_df ['중학교'] =edu_exp_2_df ['중학교']
edu_exp_3_df ['중학교'] =edu_exp_3_df ['중학교']
edu_exp_4_df ['중학교'] =edu_exp_4_df ['중학교']
edu_exp_5_df ['중학교'] =edu_exp_5_df ['중학교']
edu_exp_6_df ['중학교'] =edu_exp_6_df ['중학교']
edu_exp_7_df ['중학교'] =edu_exp_7_df ['중학교']
edu_exp_8_df ['중학교'] =edu_exp_8_df ['중학교']
edu_exp_9_df ['중학교'] =edu_exp_9_df ['중학교']
edu_exp_10_df ['중학교'] =edu_exp_10_df ['중학교']
edu_exp_11_df ['중학교'] =edu_exp_11_df ['중학교']

# '고등학교'와 '중학교' 열을 더한 값을 '응답' 열에 추가
edu_exp_1_df ['응답'] = edu_exp_1_df['고등학교'] + edu_exp_1_df['중학교']
edu_exp_2_df ['응답'] = edu_exp_2_df['고등학교'] + edu_exp_2_df['중학교']
edu_exp_3_df ['응답'] = edu_exp_3_df['고등학교'] + edu_exp_3_df['중학교']
edu_exp_4_df ['응답'] = edu_exp_4_df['고등학교'] + edu_exp_4_df['중학교']
edu_exp_5_df ['응답'] = edu_exp_5_df['고등학교'] + edu_exp_5_df['중학교']
edu_exp_6_df ['응답'] = edu_exp_6_df['고등학교'] + edu_exp_6_df['중학교']
edu_exp_7_df ['응답'] = edu_exp_7_df['고등학교'] + edu_exp_7_df['중학교']
edu_exp_8_df ['응답'] = edu_exp_8_df['고등학교'] + edu_exp_8_df['중학교']
edu_exp_9_df ['응답'] = edu_exp_9_df['고등학교'] + edu_exp_9_df['중학교']
edu_exp_10_df ['응답'] = edu_exp_10_df['고등학교'] + edu_exp_10_df['중학교']
edu_exp_11_df ['응답'] = edu_exp_11_df['고등학교'] + edu_exp_11_df['중학교']

# 예방교육 설문 전체 응답자 count
edu_exp_1_df.reset_index(inplace=True)
edu_exp_2_df.reset_index(inplace=True)
edu_exp_3_df.reset_index(inplace=True)
edu_exp_4_df.reset_index(inplace=True)
edu_exp_5_df.reset_index(inplace=True)
edu_exp_6_df.reset_index(inplace=True)
edu_exp_7_df.reset_index(inplace=True)
edu_exp_8_df.reset_index(inplace=True)
edu_exp_9_df.reset_index(inplace=True)
edu_exp_10_df.reset_index(inplace=True)
edu_exp_11_df.reset_index(inplace=True)

edu_exp_1_df = edu_exp_1_df[['시도', '고등학교', '중학교', '응답']]
edu_exp_2_df = edu_exp_2_df[['시도', '고등학교', '중학교', '응답']]
edu_exp_3_df = edu_exp_3_df[['시도', '고등학교', '중학교', '응답']]
edu_exp_4_df = edu_exp_4_df[['시도', '고등학교', '중학교', '응답']]
edu_exp_5_df = edu_exp_5_df[['시도', '고등학교', '중학교', '응답']]
edu_exp_6_df= edu_exp_6_df[['시도', '고등학교', '중학교', '응답']]
edu_exp_7_df = edu_exp_7_df[['시도', '고등학교', '중학교', '응답']]
edu_exp_8_df = edu_exp_8_df[['시도', '고등학교', '중학교', '응답']]
edu_exp_9_df = edu_exp_9_df[['시도', '고등학교', '중학교', '응답']]
edu_exp_10_df= edu_exp_10_df[['시도', '고등학교', '중학교', '응답']]
edu_exp_11_df = edu_exp_11_df[['시도', '고등학교', '중학교', '응답']]

# %% [markdown]
# ## 2) 예방교육 경험 있는 학생

# %%
# 예방교육 경험이 있는 응답자 sort
flag_1 = edu_exp[edu_exp['E_1'] == 1]
flag_2 = edu_exp[edu_exp['E_2'] == 1]
flag_3 = edu_exp[edu_exp['E_3'] == 1]
flag_4 = edu_exp[edu_exp['E_4'] == 1]
flag_5 = edu_exp[edu_exp['E_5'] == 1]
flag_6 = edu_exp[edu_exp['E_6'] == 1]
flag_7 = edu_exp[edu_exp['E_7'] == 1]
flag_8 = edu_exp[edu_exp['E_8'] == 1]
flag_9 = edu_exp[edu_exp['E_9'] == 1]
flag_10 = edu_exp[edu_exp['E_10'] == 1]
flag_11 = edu_exp[edu_exp['E_11'] == 1]

# %%
flag_8.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6825 entries, 457 to 17137
# Data columns (total 13 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   시도      6825 non-null   object
#  1   학교급     6825 non-null   object
#  2   E_1     6825 non-null   float64
#  3   E_2     6825 non-null   float64
#  4   E_3     6825 non-null   int64
#  5   E_4     6825 non-null   int64
#  6   E_5     6825 non-null   int64
#  7   E_6     6825 non-null   int64
#  8   E_7     6825 non-null   float64
#  9   E_8     6825 non-null   int64
#  10  E_9     6825 non-null   int64
#  11  E_10    6825 non-null   int64
#  12  E_11    6825 non-null   int64
# dtypes: float64(3), int64(8), object(2)
# memory usage: 746.5+ KB

# %%
# 멀티인덱스 해제
flag_1 = flag_1.groupby(['시도', '학교급']).size().unstack(fill_value=0)
flag_2 = flag_2.groupby(['시도', '학교급']).size().unstack(fill_value=0)
flag_3 = flag_3.groupby(['시도', '학교급']).size().unstack(fill_value=0)
flag_4 = flag_4.groupby(['시도', '학교급']).size().unstack(fill_value=0)
flag_5 = flag_5.groupby(['시도', '학교급']).size().unstack(fill_value=0)
flag_6 = flag_6.groupby(['시도', '학교급']).size().unstack(fill_value=0)
flag_7 = flag_7.groupby(['시도', '학교급']).size().unstack(fill_value=0)
flag_8 = flag_8.groupby(['시도', '학교급']).size().unstack(fill_value=0)
flag_9 = flag_9.groupby(['시도', '학교급']).size().unstack(fill_value=0)
flag_10 = flag_10.groupby(['시도', '학교급']).size().unstack(fill_value=0)
flag_11 = flag_11.groupby(['시도', '학교급']).size().unstack(fill_value=0)

# %%
# (1)있음 선택한 학생들 count
response_counts1 = flag_1.sum(axis=1).reset_index(name='응답1')
response_counts2 = flag_2.sum(axis=1).reset_index(name='응답1')
response_counts3 = flag_3.sum(axis=1).reset_index(name='응답1')
response_counts4 = flag_4.sum(axis=1).reset_index(name='응답1')
response_counts5 = flag_5.sum(axis=1).reset_index(name='응답1')
response_counts6 = flag_6.sum(axis=1).reset_index(name='응답1')
response_counts7 = flag_7.sum(axis=1).reset_index(name='응답1')
response_counts8 = flag_8.sum(axis=1).reset_index(name='응답1')
response_counts9 = flag_9.sum(axis=1).reset_index(name='응답1')
response_counts10 = flag_10.sum(axis=1).reset_index(name='응답1')
response_counts11 = flag_11.sum(axis=1).reset_index(name='응답1')

# %%
# 기존 데이터프레임과 새로운 데이터프레임 병합
flag_1['응답1'] = response_counts1['응답1']
flag_2['응답1'] = response_counts2['응답1']
flag_3['응답1'] = response_counts3['응답1']
flag_4['응답1'] = response_counts4['응답1']
flag_5['응답1'] = response_counts5['응답1']
flag_6['응답1'] = response_counts6['응답1']
flag_7['응답1'] = response_counts7['응답1']
flag_8['응답1'] = response_counts8['응답1']
flag_9['응답1'] = response_counts9['응답1']
flag_10['응답1'] = response_counts10['응답1']
flag_11['응답1'] = response_counts11['응답1']

# %%
# 교육경험이 있는 '고등학교'열 추가
flag_1['고등학교1'] =flag_1['고등학교']
flag_2['고등학교1'] =flag_2['고등학교']
flag_3['고등학교1'] =flag_3['고등학교']
flag_4['고등학교1'] =flag_4['고등학교']
flag_5['고등학교1'] =flag_5['고등학교']
flag_6['고등학교1'] =flag_6['고등학교']
flag_7['고등학교1'] =flag_7['고등학교']
flag_8['고등학교1'] =flag_8['고등학교']
flag_9['고등학교1'] =flag_9['고등학교']
flag_10['고등학교1'] =flag_10['고등학교']
flag_11['고등학교1'] =flag_11['고등학교']

# 교육경험이 있는 '중학교'열 추가
flag_1['중학교1'] =flag_1['중학교']
flag_2['중학교1'] =flag_2['중학교']
flag_3['중학교1'] =flag_3['중학교']
flag_4['중학교1'] =flag_4['중학교']
flag_5['중학교1'] =flag_5['중학교']
flag_6['중학교1'] =flag_6['중학교']
flag_7['중학교1'] =flag_7['중학교']
flag_8['중학교1'] =flag_8['중학교']
flag_9['중학교1'] =flag_9['중학교']
flag_10['중학교1'] =flag_10['중학교']
flag_11['중학교1'] =flag_11['중학교']

# %%
# '고등학교'와 '중학교' 열을 더한 값을 '응답' 열에 추가
flag_1['응답1'] = flag_1['고등학교1'] + flag_1['중학교1']
flag_2['응답1'] = flag_2['고등학교1'] + flag_2['중학교1']
flag_3['응답1'] = flag_3['고등학교1'] + flag_3['중학교1']
flag_4['응답1'] = flag_4['고등학교1'] + flag_4['중학교1']
flag_5['응답1'] = flag_5['고등학교1'] + flag_5['중학교1']
flag_6['응답1'] = flag_6['고등학교1'] + flag_6['중학교1']
flag_7['응답1'] = flag_7['고등학교1'] + flag_7['중학교1']
flag_8['응답1'] = flag_8['고등학교1'] + flag_8['중학교1']
flag_9['응답1'] = flag_9['고등학교1'] + flag_9['중학교1']
flag_10['응답1'] = flag_10['고등학교1'] + flag_10['중학교1']
flag_11['응답1'] = flag_11['고등학교1'] + flag_11['중학교1']

# %%
# 예방교육 설문 전체 응답자 count
flag_1.reset_index(inplace=True)
flag_2.reset_index(inplace=True)
flag_3.reset_index(inplace=True)
flag_4.reset_index(inplace=True)
flag_5.reset_index(inplace=True)
flag_6.reset_index(inplace=True)
flag_7.reset_index(inplace=True)
flag_8.reset_index(inplace=True)
flag_9.reset_index(inplace=True)
flag_10.reset_index(inplace=True)
flag_11.reset_index(inplace=True)

flag_1 = flag_1[['시도', '고등학교1', '중학교1', '응답1']]
flag_2 = flag_2[['시도', '고등학교1', '중학교1', '응답1']]
flag_3 = flag_3[['시도', '고등학교1', '중학교1', '응답1']]
flag_4 = flag_4[['시도', '고등학교1', '중학교1', '응답1']]
flag_5 = flag_5[['시도', '고등학교1', '중학교1', '응답1']]
flag_6 = flag_6[['시도', '고등학교1', '중학교1', '응답1']]
flag_7 = flag_7[['시도', '고등학교1', '중학교1', '응답1']]
flag_8 = flag_8[['시도', '고등학교1', '중학교1', '응답1']]
flag_9 = flag_9[['시도', '고등학교1', '중학교1', '응답1']]
flag_10 = flag_10[['시도', '고등학교1', '중학교1', '응답1']]
flag_11 = flag_11[['시도', '고등학교1', '중학교1', '응답1']]

# %% [markdown]
# ## 3) 예방교육 경험 有 청소년, 퍼센트 계산

# %%
#음주 예방 교육 有
edu_exp_1_df['high_%'] = flag_1['고등학교1'] / edu_exp_1_df['고등학교'] * 100
edu_exp_1_df['middle_%'] = flag_1['중학교1'] / edu_exp_1_df['중학교'] * 100
edu_exp_1_df['total_%'] = flag_1['응답1'] / edu_exp_1_df['응답'] * 100
edu_exp_1_df.head()
# Out:
# 학교급  시도  고등학교   중학교    응답     high_%   middle_%    total_%
# 0    강원   268   258   526  66.044776  70.155039  68.060837
# 1    경기   868  1046  1914  60.138249  62.045889  61.180773
# 2    경남   391   324   715  57.033248  58.950617  57.902098
# 3    경북   352   261   613  52.840909  47.892720  50.734095
# 4    광주   311   219   530  48.874598  61.643836  54.150943

# %%
#흡연 예방 교육 有
edu_exp_2_df['high_%'] = flag_2['고등학교1'] / edu_exp_2_df['고등학교'] * 100
edu_exp_2_df['middle_%'] = flag_2['중학교1'] / edu_exp_2_df['중학교'] * 100
edu_exp_2_df['total_%'] = flag_2['응답1'] / edu_exp_2_df['응답'] * 100
edu_exp_2_df.head()
# Out:
# 학교급  시도  고등학교   중학교    응답     high_%   middle_%    total_%
# 0    강원   268   258   526  85.074627  89.147287  87.072243
# 1    경기   868  1046  1914  77.995392  89.005736  84.012539
# 2    경남   391   324   715  89.002558  90.740741  89.790210
# 3    경북   352   261   613  81.818182  83.524904  82.544861
# 4    광주   311   219   530  84.565916  90.867580  87.169811

# %%
#학교폭력 예방 교육 有
edu_exp_3_df['high_%'] = flag_3['고등학교1'] / edu_exp_3_df['고등학교'] * 100
edu_exp_3_df['middle_%'] = flag_3['중학교1'] / edu_exp_3_df['중학교'] * 100
edu_exp_3_df['total_%'] = flag_3['응답1'] / edu_exp_3_df['응답'] * 100
edu_exp_3_df.head()
# Out:
# 학교급  시도  고등학교   중학교    응답     high_%   middle_%    total_%
# 0    강원   268   258   526  91.044776  93.410853  92.205323
# 1    경기   868  1046  1914  89.400922  97.992352  94.096134
# 2    경남   391   324   715  94.629156  96.913580  95.664336
# 3    경북   352   261   613  90.340909  95.019157  92.332790
# 4    광주   311   219   530  89.710611  98.173516  93.207547

# %%
#성폭력 예방 교육 有
edu_exp_4_df['high_%'] = flag_4['고등학교1'] / edu_exp_4_df['고등학교'] * 100
edu_exp_4_df['middle_%'] = flag_4['중학교1'] / edu_exp_4_df['중학교'] * 100
edu_exp_4_df['total_%'] = flag_4['응답1'] / edu_exp_4_df['응답'] * 100
edu_exp_4_df.head()
# Out:
# 학교급  시도  고등학교   중학교    응답     high_%   middle_%    total_%
# 0    강원   268   258   526  86.194030  90.310078  88.212928
# 1    경기   868  1046  1914  86.175115  93.594646  90.229885
# 2    경남   391   324   715  91.560102  97.222222  94.125874
# 3    경북   352   261   613  86.647727  93.103448  89.396411
# 4    광주   311   219   530  83.279743  97.260274  89.056604

# %%
#디지털 성범죄 예방 교육 有
edu_exp_5_df['high_%'] = flag_5['고등학교1'] / edu_exp_5_df['고등학교'] * 100
edu_exp_5_df['middle_%'] = flag_5['중학교1'] / edu_exp_5_df['중학교'] * 100
edu_exp_5_df['total_%'] = flag_5['응답1'] / edu_exp_5_df['응답'] * 100
edu_exp_5_df.head()
# Out:
# 학교급  시도  고등학교   중학교    응답     high_%   middle_%    total_%
# 0    강원   268   258   526  82.089552  86.434109  84.220532
# 1    경기   868  1046  1914  83.986175  91.204589  87.931034
# 2    경남   391   324   715  85.421995  95.987654  90.209790
# 3    경북   352   261   613  81.818182  86.206897  83.686786
# 4    광주   311   219   530  79.421222  94.063927  85.471698

# %%
#성교육 有
edu_exp_6_df['high_%'] = flag_6['고등학교1'] / edu_exp_6_df['고등학교'] * 100
edu_exp_6_df['middle_%'] = flag_6['중학교1'] / edu_exp_6_df['중학교'] * 100
edu_exp_6_df['total_%'] = flag_6['응답1'] / edu_exp_6_df['응답'] * 100
edu_exp_6_df.head()
# Out:
# 학교급  시도  고등학교   중학교    응답     high_%   middle_%    total_%
# 0    강원   268   258   526  80.223881  89.147287  84.600760
# 1    경기   868  1046  1914  77.188940  86.806883  82.445141
# 2    경남   391   324   715  82.864450  95.061728  88.391608
# 3    경북   352   261   613  80.113636  90.421456  84.502447
# 4    광주   311   219   530  74.919614  92.694064  82.264151

# %%
#성매매 예방 교육 有
edu_exp_7_df['high_%'] = flag_7['고등학교1'] / edu_exp_7_df['고등학교'] * 100
edu_exp_7_df['middle_%'] = flag_7['중학교1'] / edu_exp_7_df['중학교'] * 100
edu_exp_7_df['total_%'] = flag_7['응답1'] / edu_exp_7_df['응답'] * 100
edu_exp_7_df.head()
# Out:
# 학교급  시도  고등학교   중학교    응답     high_%   middle_%    total_%
# 0    강원   268   258   526  62.313433  58.527132  60.456274
# 1    경기   868  1046  1914  69.815668  64.627151  66.980146
# 2    경남   391   324   715  66.496164  75.308642  70.489510
# 3    경북   352   261   613  67.045455  55.938697  62.316476
# 4    광주   311   219   530  65.594855  72.146119  68.301887

# %%
#성인매체 피해 예방교육 有
edu_exp_8_df['high_%'] = flag_8['고등학교1'] / edu_exp_8_df['고등학교'] * 100
edu_exp_8_df['middle_%'] = flag_8['중학교1'] / edu_exp_8_df['중학교'] * 100
edu_exp_8_df['total_%'] = flag_8['응답1'] / edu_exp_8_df['응답'] * 100
edu_exp_8_df.head()
# Out:
# 학교급  시도  고등학교   중학교    응답     high_%   middle_%    total_%
# 0    강원   268   258   526  47.761194  61.240310  54.372624
# 1    경기   868  1046  1914  52.534562  61.472275  57.419018
# 2    경남   391   324   715  52.429668  64.814815  58.041958
# 3    경북   352   261   613  50.284091  60.536398  54.649266
# 4    광주   311   219   530  45.337621  61.187215  51.886792

# %%
#온라인 도박 피햬 예방교육 有
edu_exp_9_df['high_%'] = flag_9['고등학교1'] / edu_exp_9_df['고등학교'] * 100
edu_exp_9_df['middle_%'] = flag_9['중학교1'] / edu_exp_9_df['중학교'] * 100
edu_exp_9_df['total_%'] = flag_9['응답1'] / edu_exp_9_df['응답'] * 100
edu_exp_9_df.head()
# Out:
# 학교급  시도  고등학교   중학교    응답     high_%   middle_%    total_%
# 0    강원   268   258   526  61.940299  70.542636  66.159696
# 1    경기   868  1046  1914  51.728111  48.183556  49.791014
# 2    경남   391   324   715  61.381074  63.271605  62.237762
# 3    경북   352   261   613  47.443182  63.984674  54.486134
# 4    광주   311   219   530  60.128617  53.881279  57.547170

# %%
#인터넷/스마트폰 이용교육 有
edu_exp_10_df['high_%'] = flag_10['고등학교1'] / edu_exp_10_df['고등학교'] * 100
edu_exp_10_df['middle_%'] = flag_10['중학교1'] / edu_exp_10_df['중학교'] * 100
edu_exp_10_df['total_%'] = flag_10['응답1'] / edu_exp_10_df['응답'] * 100
edu_exp_10_df.head()
# Out:
# 학교급  시도  고등학교   중학교    응답     high_%   middle_%    total_%
# 0    강원   268   258   526  68.283582  72.868217  70.532319
# 1    경기   868  1046  1914  79.262673  86.137667  83.019854
# 2    경남   391   324   715  75.447570  87.654321  80.979021
# 3    경북   352   261   613  67.897727  72.413793  69.820555
# 4    광주   311   219   530  67.202572  82.648402  73.584906

# %%
#개인정보보호 교육 有
edu_exp_11_df['high_%'] = flag_11['고등학교1'] / edu_exp_11_df['고등학교'] * 100
edu_exp_11_df['middle_%'] = flag_11['중학교1'] / edu_exp_11_df['중학교'] * 100
edu_exp_11_df['total_%'] = flag_11['응답1'] / edu_exp_11_df['응답'] * 100
edu_exp_11_df.head()
# Out:
# 학교급  시도  고등학교   중학교    응답     high_%   middle_%    total_%
# 0    강원   268   258   526  56.343284  66.279070  61.216730
# 1    경기   868  1046  1914  68.317972  78.967495  74.137931
# 2    경남   391   324   715  64.450128  72.839506  68.251748
# 3    경북   352   261   613  55.113636  65.900383  59.706362
# 4    광주   311   219   530  58.520900  73.059361  64.528302

# %% [markdown]
# ## 4) 예방교육 도움정도

# %% [markdown]
# ### 4-1) 중/고등학교 분리

# %%
# 'E_1'부터 'E_7'까지의 열에서 값이 1인 행들만 선택하여 새로운 데이터프레임 생성
df_exp_y = df[(df['E_1'] == 1) & (df['E_2'] == 1) & (df['E_3'] == 1) & (df['E_4'] == 1) & (df['E_5'] == 1) & (df['E_6'] == 1) & (df['E_7'] == 1)& (df['E_8'] == 1)& (df['E_9'] == 1)& (df['E_10'] == 1)& (df['E_11'] == 1)]

# %%
df_exp_y.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3676 entries, 457 to 17137
# Data columns (total 24 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   시도      3676 non-null   object
#  1   학교급     3676 non-null   object
#  2   E_1     3676 non-null   float64
#  3   E_2     3676 non-null   float64
#  4   E_3     3676 non-null   int64
#  5   E_4     3676 non-null   int64
#  6   E_5     3676 non-null   int64
#  7   E_6     3676 non-null   int64
#  8   E_7     3676 non-null   float64
#  9   A_1     3676 non-null   float64
#  10  A_2     3676 non-null   float64
#  11  A_3     3676 non-null   float64
#  12  A_4     3676 non-null   float64
#  13  A_5     3676 non-null   float64
#  14  A_6     3676 non-null   float64
#  15  A_7     3676 non-null   float64
#  16  E_8     3676 non-null   int64
#  17  E_9     3676 non-null   int64
#  18  E_10    3676 non-null   int64
#  19  E_11    3676 non-null   int64
#  20  A_8     3676 non-null   float64
# ...

# %%
# 예방교육 도움 여부 문항 df
edu_assist = df_exp_y[[
    '시도',
    '학교급',
    'A_1',
    'A_2',
    'A_3',
    'A_4',
    'A_5',
    'A_6',
    'A_7',
    'A_8',
    'A_9',
    'A_10',
    'A_11'
]]

# (9)응답자 (1)으로 분류, 4점척도 점수로 전처리
edu_assist['A_1'] = edu_assist['A_1'].replace({1: 0, 2: 33.3, 3: 66.7, 4: 100, 9:0})
edu_assist['A_2'] = edu_assist['A_2'].replace({1: 0, 2: 33.3, 3: 66.7, 4: 100, 9:0})
edu_assist['A_3'] = edu_assist['A_3'].replace({1: 0, 2: 33.3, 3: 66.7, 4: 100, 9:0})
edu_assist['A_4'] = edu_assist['A_4'].replace({1: 0, 2: 33.3, 3: 66.7, 4: 100, 9:0})
edu_assist['A_5'] = edu_assist['A_5'].replace({1: 0, 2: 33.3, 3: 66.7, 4: 100, 9:0})
edu_assist['A_6'] = edu_assist['A_6'].replace({1: 0, 2: 33.3, 3: 66.7, 4: 100, 9:0})
edu_assist['A_7'] = edu_assist['A_7'].replace({1: 0, 2: 33.3, 3: 66.7, 4: 100, 9:0})
edu_assist['A_8'] = edu_assist['A_8'].replace({1: 0, 2: 33.3, 3: 66.7, 4: 100, 9:0})
edu_assist['A_9'] = edu_assist['A_9'].replace({1: 0, 2: 33.3, 3: 66.7, 4: 100, 9:0})
edu_assist['A_10'] = edu_assist['A_10'].replace({1: 0, 2: 33.3, 3: 66.7, 4: 100, 9:0})
edu_assist['A_11'] = edu_assist['A_11'].replace({1: 0, 2: 33.3, 3: 66.7, 4: 100, 9:0})

# # (9)응답자 (1)으로 분류
# edu_assist['A_1'] = edu_assist['A_1'].replace({9: 1})
# edu_assist['A_2'] = edu_assist['A_2'].replace({9: 1})
# edu_assist['A_3'] = edu_assist['A_3'].replace({9: 1})
# edu_assist['A_4'] = edu_assist['A_4'].replace({9: 1})
# edu_assist['A_5'] = edu_assist['A_5'].replace({9: 1})
# edu_assist['A_6'] = edu_assist['A_6'].replace({9: 1})
# edu_assist['A_7'] = edu_assist['A_7'].replace({9: 1})

#교육별 분류
edu_assist_1 = edu_assist[['시도','학교급','A_1']] #음주 예방 교육
edu_assist_2 = edu_assist[['시도','학교급','A_2']] #흡연 예방 교육
edu_assist_3 = edu_assist[['시도','학교급','A_3']] #학교폭력 예방 교육
edu_assist_4 = edu_assist[['시도','학교급','A_4']] #성폭력 예방 교육
edu_assist_5 = edu_assist[['시도','학교급','A_5']] #디지털 성범죄 예방 교육
edu_assist_6 = edu_assist[['시도','학교급','A_6']] #성교육
edu_assist_7 = edu_assist[['시도','학교급','A_7']] #성매매 예방 교육
edu_assist_8 = edu_assist[['시도','학교급','A_8']] #성인매체 피해 예방교육
edu_assist_9 = edu_assist[['시도','학교급','A_9']] #온라인 도박 피햬 예방교육
edu_assist_10 = edu_assist[['시도','학교급','A_10']] #인터넷/스마트폰 이용교육
edu_assist_11 = edu_assist[['시도','학교급','A_11']] #개인정보보호 교육

# %%
edu_assist_1.head()
# Out:
#      시도  학교급    A_1
# 457  서울  중학교   66.7
# 458  서울  중학교  100.0
# 463  서울  중학교   33.3
# 464  서울  중학교   66.7
# 471  서울  중학교    0.0

# %%
# 리커트척도 평균
edu_assist_1 = edu_assist_1.groupby(['시도', '학교급']).mean().reset_index()
edu_assist_2 = edu_assist_2.groupby(['시도', '학교급']).mean().reset_index()
edu_assist_3  = edu_assist_3.groupby(['시도', '학교급']).mean().reset_index()
edu_assist_4  = edu_assist_4.groupby(['시도', '학교급']).mean().reset_index()
edu_assist_5 = edu_assist_5.groupby(['시도', '학교급']).mean().reset_index()
edu_assist_6 = edu_assist_6.groupby(['시도', '학교급']).mean().reset_index()
edu_assist_7 = edu_assist_7.groupby(['시도', '학교급']).mean().reset_index()
edu_assist_8  = edu_assist_8.groupby(['시도', '학교급']).mean().reset_index()
edu_assist_9 = edu_assist_9.groupby(['시도', '학교급']).mean().reset_index()
edu_assist_10 = edu_assist_10.groupby(['시도', '학교급']).mean().reset_index()
edu_assist_11 = edu_assist_11.groupby(['시도', '학교급']).mean().reset_index()

# %%
# '학교급' 열의 값이 '중학교'인 데이터프레임
edu_assist_1_MS = edu_assist_1[edu_assist_1['학교급'] == '중학교']
edu_assist_2_MS = edu_assist_2[edu_assist_2['학교급'] == '중학교']
edu_assist_3_MS = edu_assist_3[edu_assist_3['학교급'] == '중학교']
edu_assist_4_MS = edu_assist_4[edu_assist_4['학교급'] == '중학교']
edu_assist_5_MS = edu_assist_5[edu_assist_5['학교급'] == '중학교']
edu_assist_6_MS = edu_assist_6[edu_assist_6['학교급'] == '중학교']
edu_assist_7_MS = edu_assist_7[edu_assist_7['학교급'] == '중학교']
edu_assist_8_MS = edu_assist_8[edu_assist_8['학교급'] == '중학교']
edu_assist_9_MS = edu_assist_9[edu_assist_9['학교급'] == '중학교']
edu_assist_10_MS = edu_assist_10[edu_assist_10['학교급'] == '중학교']
edu_assist_11_MS = edu_assist_11[edu_assist_11['학교급'] == '중학교']

# '학교급' 열의 값이 '고등학교'인 데이터프레임
edu_assist_1_HS = edu_assist_1[edu_assist_1['학교급'] == '고등학교']
edu_assist_2_HS = edu_assist_2[edu_assist_2['학교급'] == '고등학교']
edu_assist_3_HS = edu_assist_3[edu_assist_3['학교급'] == '고등학교']
edu_assist_4_HS = edu_assist_4[edu_assist_4['학교급'] == '고등학교']
edu_assist_5_HS = edu_assist_5[edu_assist_5['학교급'] == '고등학교']
edu_assist_6_HS = edu_assist_6[edu_assist_6['학교급'] == '고등학교']
edu_assist_7_HS = edu_assist_7[edu_assist_7['학교급'] == '고등학교']
edu_assist_8_HS = edu_assist_8[edu_assist_8['학교급'] == '고등학교']
edu_assist_9_HS = edu_assist_9[edu_assist_9['학교급'] == '고등학교']
edu_assist_10_HS = edu_assist_10[edu_assist_10['학교급'] == '고등학교']
edu_assist_11_HS = edu_assist_11[edu_assist_11['학교급'] == '고등학교']

# %%
# 중학교 컬럼명 리네임
edu_assist_1_MS.rename(columns={'A_1': 'middle_A_1%'}, inplace=True)
edu_assist_2_MS.rename(columns={'A_2': 'middle_A_2%'}, inplace=True)
edu_assist_3_MS.rename(columns={'A_3': 'middle_A_3%'}, inplace=True)
edu_assist_4_MS.rename(columns={'A_4': 'middle_A_4%'}, inplace=True)
edu_assist_5_MS.rename(columns={'A_5': 'middle_A_5%'}, inplace=True)
edu_assist_6_MS.rename(columns={'A_6': 'middle_A_6%'}, inplace=True)
edu_assist_7_MS.rename(columns={'A_7': 'middle_A_7%'}, inplace=True)
edu_assist_8_MS.rename(columns={'A_8': 'middle_A_8%'}, inplace=True)
edu_assist_9_MS.rename(columns={'A_9': 'middle_A_9%'}, inplace=True)
edu_assist_10_MS.rename(columns={'A_10': 'middle_A_10%'}, inplace=True)
edu_assist_11_MS.rename(columns={'A_11': 'middle_A_11%'}, inplace=True)

# 중학교 학급삭제
edu_assist_1_MS.drop(columns='학교급', inplace=True)
edu_assist_2_MS.drop(columns='학교급', inplace=True)
edu_assist_3_MS.drop(columns='학교급', inplace=True)
edu_assist_4_MS.drop(columns='학교급', inplace=True)
edu_assist_5_MS.drop(columns='학교급', inplace=True)
edu_assist_6_MS.drop(columns='학교급', inplace=True)
edu_assist_7_MS.drop(columns='학교급', inplace=True)
edu_assist_8_MS.drop(columns='학교급', inplace=True)
edu_assist_9_MS.drop(columns='학교급', inplace=True)
edu_assist_10_MS.drop(columns='학교급', inplace=True)
edu_assist_11_MS.drop(columns='학교급', inplace=True)

# %%
# 고등학교 컬럼명 리네임
edu_assist_1_HS.rename(columns={'A_1': 'high_A_1%'}, inplace=True)
edu_assist_2_HS.rename(columns={'A_2': 'high_A_2%'}, inplace=True)
edu_assist_3_HS.rename(columns={'A_3': 'high_A_3%'}, inplace=True)
edu_assist_4_HS.rename(columns={'A_4': 'high_A_4%'}, inplace=True)
edu_assist_5_HS.rename(columns={'A_5': 'high_A_5%'}, inplace=True)
edu_assist_6_HS.rename(columns={'A_6': 'high_A_6%'}, inplace=True)
edu_assist_7_HS.rename(columns={'A_7': 'high_A_7%'}, inplace=True)
edu_assist_8_HS.rename(columns={'A_8': 'high_A_8%'}, inplace=True)
edu_assist_9_HS.rename(columns={'A_9': 'high_A_9%'}, inplace=True)
edu_assist_10_HS.rename(columns={'A_10': 'high_A_10%'}, inplace=True)
edu_assist_11_HS.rename(columns={'A_11': 'high_A_11%'}, inplace=True)

# 고등학교 학급삭제
edu_assist_1_HS.drop(columns='학교급', inplace=True)
edu_assist_2_HS.drop(columns='학교급', inplace=True)
edu_assist_3_HS.drop(columns='학교급', inplace=True)
edu_assist_4_HS.drop(columns='학교급', inplace=True)
edu_assist_5_HS.drop(columns='학교급', inplace=True)
edu_assist_6_HS.drop(columns='학교급', inplace=True)
edu_assist_7_HS.drop(columns='학교급', inplace=True)
edu_assist_8_HS.drop(columns='학교급', inplace=True)
edu_assist_9_HS.drop(columns='학교급', inplace=True)
edu_assist_10_HS.drop(columns='학교급', inplace=True)
edu_assist_11_HS.drop(columns='학교급', inplace=True)

# %%
#확인
print(edu_assist_1_MS)
print(edu_assist_1_HS)
# Out:
#     시도  middle_A_1%
# 1   강원    62.448101
# 3   경기    55.963177
# 5   경남    60.378889
# 7   경북    68.258730
# 9   광주    53.063380
# 11  대구    66.071818
# 13  대전    64.561905
# 15  부산    63.372072
# 17  서울    60.186425
# 19  세종    66.131148
# 21  울산    68.322772
# 23  인천    64.842857
# 25  전남    66.672727
# 27  전북    58.340278
# 29  제주    69.761111
# 31  충남    60.075248
# 33  충북    64.921053
#     시도  high_A_1%
# 0   강원  57.394937
# 2   경기  46.023134
# 4   경남  56.373171
# 6   경북  54.225301
# 8   광주  49.547222
# 10  대구  55.183621
# 12  대전  50.344898
# 14  부산  57.703077
# 16  서울  47.532593
# 18  세종  48.828169
# 20  울산  52.785606
# 22  인천  55.749580
# 24  전남  56.526087
# 26  전북  56.738462
# 28  제주  64.086408
# 30  충남  42.347297
# 32  충북  48.489899

# %%
# 중학교 데이터프레임의 인덱스를 시도로 설정
edu_assist_1_MS.set_index('시도', inplace=True)
edu_assist_2_MS.set_index('시도', inplace=True)
edu_assist_3_MS.set_index('시도', inplace=True)
edu_assist_4_MS.set_index('시도', inplace=True)
edu_assist_5_MS.set_index('시도', inplace=True)
edu_assist_6_MS.set_index('시도', inplace=True)
edu_assist_7_MS.set_index('시도', inplace=True)
edu_assist_8_MS.set_index('시도', inplace=True)
edu_assist_9_MS.set_index('시도', inplace=True)
edu_assist_10_MS.set_index('시도', inplace=True)
edu_assist_11_MS.set_index('시도', inplace=True)

# %%
# 고등학교 데이터프레임의 인덱스를 시도로 설정
edu_assist_1_HS.set_index('시도', inplace=True)
edu_assist_2_HS.set_index('시도', inplace=True)
edu_assist_3_HS.set_index('시도', inplace=True)
edu_assist_4_HS.set_index('시도', inplace=True)
edu_assist_5_HS.set_index('시도', inplace=True)
edu_assist_6_HS.set_index('시도', inplace=True)
edu_assist_7_HS.set_index('시도', inplace=True)
edu_assist_8_HS.set_index('시도', inplace=True)
edu_assist_9_HS.set_index('시도', inplace=True)
edu_assist_10_HS.set_index('시도', inplace=True)
edu_assist_11_HS.set_index('시도', inplace=True)

# %% [markdown]
# ### 4-2) 전체

# %%
# 예방교육 도움 여부 문항 df
edu_assist1 = df_exp_y[[
    '시도',
    '학교급',
    'A_1',
    'A_2',
    'A_3',
    'A_4',
    'A_5',
    'A_6',
    'A_7',
    'A_8',
    'A_9',
    'A_10',
    'A_11'
]]

# %%
# (9)응답자 (1)으로 분류
edu_assist1['A_1'] = edu_assist1['A_1'].replace({1: 0, 2: 33.3, 3: 66.7, 4: 100, 9:0})
edu_assist1['A_2'] = edu_assist1['A_2'].replace({1: 0, 2: 33.3, 3: 66.7, 4: 100, 9:0})
edu_assist1['A_3'] = edu_assist1['A_3'].replace({1: 0, 2: 33.3, 3: 66.7, 4: 100, 9:0})
edu_assist1['A_4'] = edu_assist1['A_4'].replace({1: 0, 2: 33.3, 3: 66.7, 4: 100, 9:0})
edu_assist1['A_5'] = edu_assist1['A_5'].replace({1: 0, 2: 33.3, 3: 66.7, 4: 100, 9:0})
edu_assist1['A_6'] = edu_assist1['A_6'].replace({1: 0, 2: 33.3, 3: 66.7, 4: 100, 9:0})
edu_assist1['A_7'] = edu_assist1['A_7'].replace({1: 0, 2: 33.3, 3: 66.7, 4: 100, 9:0})
edu_assist1['A_8'] = edu_assist1['A_8'].replace({1: 0, 2: 33.3, 3: 66.7, 4: 100, 9:0})
edu_assist1['A_9'] = edu_assist1['A_9'].replace({1: 0, 2: 33.3, 3: 66.7, 4: 100, 9:0})
edu_assist1['A_10'] = edu_assist1['A_10'].replace({1: 0, 2: 33.3, 3: 66.7, 4: 100, 9:0})
edu_assist1['A_11'] = edu_assist1['A_11'].replace({1: 0, 2: 33.3, 3: 66.7, 4: 100, 9:0})

# %%
#교육별 분류
edu_assist1_1 = edu_assist1[['시도','학교급','A_1']] #음주 예방 교육
edu_assist1_2 = edu_assist1[['시도','학교급','A_2']] #흡연 예방 교육
edu_assist1_3 = edu_assist1[['시도','학교급','A_3']] #학교폭력 예방 교육
edu_assist1_4 = edu_assist1[['시도','학교급','A_4']] #성폭력 예방 교육
edu_assist1_5 = edu_assist1[['시도','학교급','A_5']] #디지털 성범죄 예방 교육
edu_assist1_6 = edu_assist1[['시도','학교급','A_6']] #성교육
edu_assist1_7 = edu_assist1[['시도','학교급','A_7']] #성매매 예방 교육
edu_assist1_8 = edu_assist1[['시도','학교급','A_8']] #성인매체 피해 예방교육
edu_assist1_9 = edu_assist1[['시도','학교급','A_9']] #온라인 도박 피햬 예방교육
edu_assist1_10 = edu_assist1[['시도','학교급','A_10']] #인터넷/스마트폰 이용교육
edu_assist1_11 = edu_assist1[['시도','학교급','A_11']] #개인정보보호 교육

# %%
# 전체 리커트 평균
edu_assist1_1= edu_assist1_1.groupby('시도')['A_1'].mean().reset_index()
edu_assist1_2= edu_assist1_2.groupby('시도')['A_2'].mean().reset_index()
edu_assist1_3= edu_assist1_3.groupby('시도')['A_3'].mean().reset_index()
edu_assist1_4= edu_assist1_4.groupby('시도')['A_4'].mean().reset_index()
edu_assist1_5= edu_assist1_5.groupby('시도')['A_5'].mean().reset_index()
edu_assist1_6= edu_assist1_6.groupby('시도')['A_6'].mean().reset_index()
edu_assist1_7= edu_assist1_7.groupby('시도')['A_7'].mean().reset_index()
edu_assist1_8= edu_assist1_8.groupby('시도')['A_8'].mean().reset_index()
edu_assist1_9= edu_assist1_9.groupby('시도')['A_9'].mean().reset_index()
edu_assist1_10= edu_assist1_10.groupby('시도')['A_10'].mean().reset_index()
edu_assist1_11= edu_assist1_11.groupby('시도')['A_11'].mean().reset_index()

# %%
# 컬럼명 변경
edu_assist1_1.rename(columns={'A_1': 'total_A_1%'}, inplace=True)
edu_assist1_2.rename(columns={'A_2': 'total_A_2%'}, inplace=True)
edu_assist1_3.rename(columns={'A_3': 'total_A_3%'}, inplace=True)
edu_assist1_4.rename(columns={'A_4': 'total_A_4%'}, inplace=True)
edu_assist1_5.rename(columns={'A_5': 'total_A_5%'}, inplace=True)
edu_assist1_6.rename(columns={'A_6': 'total_A_6%'}, inplace=True)
edu_assist1_7.rename(columns={'A_7': 'total_A_7%'}, inplace=True)
edu_assist1_8.rename(columns={'A_8': 'total_A_8%'}, inplace=True)
edu_assist1_9.rename(columns={'A_9': 'total_A_9%'}, inplace=True)
edu_assist1_10.rename(columns={'A_10': 'total_A_10%'}, inplace=True)
edu_assist1_11.rename(columns={'A_11': 'total_A_11%'}, inplace=True)

# %% [markdown]
# ## 5) 문항별 퍼센테이지 합치기

# %% [markdown]
# ### 5-0) 예방교육 경험

# %% [markdown]
# #### 5-1) 음주예방교육

# %%
#예방교육 도움정도 병합
alcohol_assist_df = pd.merge(edu_assist_1_MS,edu_assist_1_HS, on='시도', how='outer')
alcohol_assist_df = pd.merge(alcohol_assist_df, edu_assist1_1, on='시도', how='outer')

alcohol_assist_df .rename(columns={
    'high_A_1%': '음주_도움정도_고등', #음주_예방교육 도움 정도 고등학생
    'middle_A_1%': '음주_도움정도_중등', #음주_예방교육 도움 정도 중학생
    'total_A_1%': 'T_102' #음주_예방교육 도움 정도 청소년 전체
    }, inplace=True)

# %%
#음주 예방 교육 최종
alcohol_prevent_edu = pd.merge(edu_exp_1_df,alcohol_assist_df, on='시도', how='outer')

#컬럼 최종
alcohol_prevent_edu.rename(columns={
    'high_%': '음주_예방교육_고등_Y', #음주_예방교육 경험이 있는 고등학생
    'middle_%': '음주_예방교육_중등_Y', #음주_예방교육 경험이 있는 중학생
    'total_%': 'T_103', #음주_예방교육 경험이 있는 청소년 전체
    }, inplace=True)

#소수점 둘째자리
alcohol_prevent_edu = alcohol_prevent_edu.round(2)

# %%
# 최종파일
alcohol_prevent_edu_final = alcohol_prevent_edu[['시도','T_102','T_103']]
# alcohol_prevent_edu_final

# %% [markdown]
# #### 5-2) 흡연 예방 교육

# %%
#예방교육 도움정도 병합
smoke_assist_df = pd.merge(edu_assist_2_MS,edu_assist_2_HS, on='시도', how='outer')
smoke_assist_df = pd.merge(smoke_assist_df, edu_assist1_2, on='시도', how='outer')

smoke_assist_df .rename(columns={
    'high_A_2%': '흡연_도움정도_고등', #흡연_예방교육 도움정도 고등학생
    'middle_A_2%': '흡연_도움정도_중등', #흡연_예방교육 도움정도 중학생
    'total_A_2%': 'T_104' #흡연_예방교육 도움정도 청소년 전체
    }, inplace=True)

# %%
#흡연 예방 교육
smoke_prevent_edu = pd.merge(edu_exp_2_df, smoke_assist_df, on='시도', how='outer')

#컬럼 최종
smoke_prevent_edu .rename(columns={
    'high_%': '흡연_예방교육_고등_Y', #흡연_예방교육 경험이 있는 고등학생
    'middle_%': '흡연_예방교육_중등_Y', #흡연_예방교육 경험이 있는 중학생
    'total_%': 'T_105', #흡연_예방교육 경험이 있는 청소년 전체
    }, inplace=True)

#소수점 둘째자리
smoke_prevent_edu = smoke_prevent_edu.round(2)

# %%
# 최종파일
smoke_prevent_edu_final = smoke_prevent_edu[['시도','T_104','T_105']]
# smoke_prevent_edu_final

# %% [markdown]
# #### 5-3)학교폭력 예방 교육

# %%
#예방교육 도움정도 병합
violence_assist_df = pd.merge(edu_assist_3_MS,edu_assist_3_HS, on='시도', how='outer')
violence_assist_df = pd.merge(violence_assist_df , edu_assist1_3, on='시도', how='outer')

violence_assist_df.rename(columns={
    'high_A_3%': '학교폭력_도움정도_고등', #학교폭력_예방교육 도움정도 고등학생
    'middle_A_3%': '학교폭력_도움정도_중등', #학교폭력_예방교육 도움정도 중학생
    'total_A_3%': 'T_106' #학교폭력_예방교육 도움정도 청소년 전체
    }, inplace=True)

# %%
#학교폭력 예방 교육 최종
violence_prevent_edu = pd.merge(edu_exp_3_df, violence_assist_df, on='시도', how='outer')

#컬럼 최종
violence_prevent_edu.rename(columns={
    'high_%': '학교폭력_예방교육_고등_Y', #학교폭력_예방교육 경험이 있는 고등학생
    'middle_%': '학교폭력_예방교육_중등_Y', #학교폭력_예방교육 경험이 있는 중학생
    'total_%': 'T_107', #학교폭력_예방교육 경험이 있는 청소년 전체
    }, inplace=True)

#소수점 둘째자리
violence_prevent_edu  = violence_prevent_edu.round(2)

# %%
# 최종파일
violence_prevent_edu_final = violence_prevent_edu[['시도','T_106','T_107']]

# %% [markdown]
# #### 5-4) 성폭력 예방 교육

# %%
#예방교육 도움정도 병합
sexual_assist_df = pd.merge(edu_assist_4_MS,edu_assist_4_HS, on='시도', how='outer')
sexual_assist_df = pd.merge(sexual_assist_df, edu_assist1_4, on='시도', how='outer')

sexual_assist_df.rename(columns={
    'high_A_4%': '성폭력_도움정도_고등', #성폭력_예방교육 도움정도 고등학생
    'middle_A_4%': '성폭력_도움정도_중등',  #성폭력_예방교육 도움정도 중학생
    'total_A_4%': 'T_108' #성폭력_예방교육 도움정도 청소년 전체
    }, inplace=True)

# %%
#성폭력 예방 교육
sexual_prevent_edu = pd.merge(edu_exp_4_df, sexual_assist_df, on='시도', how='outer')

#컬럼 최종
sexual_prevent_edu.rename(columns={
    'high_%': '성폭력_예방교육_고등_Y', #성폭력_예방교육 경험이 있는 고등학생
    'middle_%': '성폭력_예방교육_중등_Y', #성폭력_예방교육 경험이 있는 중학생
    'total_%': 'T_109', #성폭력_예방교육 경험이 있는 청소년 전체
    }, inplace=True)
#소수점 둘째자리
sexual_prevent_edu = sexual_prevent_edu.round(2)

# %%
# 최종파일
sexual_prevent_edu_final = sexual_prevent_edu[['시도','T_108','T_109']]

# %% [markdown]
# #### 5-5) 디지털 성범죄 예방 교육

# %%
#예방교육 도움정도 병합
digital_assist_df = pd.merge(edu_assist_5_MS,edu_assist_5_HS, on='시도', how='outer')
digital_assist_df = pd.merge(digital_assist_df, edu_assist1_5, on='시도', how='outer')

digital_assist_df.rename(columns={
    'high_A_5%': '디지털성범죄_도움정도_고등', #디지털성범죄_예방교육 도움정도 고등학생
    'middle_A_5%': '디지털성범죄_도움정도_중등', #디지털성범죄_예방교육 도움정도 중학생
    'total_A_5%': 'T_110' #디지털성범죄_예방교육 도움정도 청소년 전체
    }, inplace=True)

# %%
#디지털 성범죄 예방 교육
digital_prevent_edu = pd.merge(edu_exp_5_df, digital_assist_df, on='시도', how='outer')

#컬럼 최종
digital_prevent_edu.rename(columns={
    'high_%': '디지털성범죄_예방교육_고등_Y', #디지털성범죄_예방교육 경험이 있는 고등학생
    'middle_%': '디지털성범죄_예방교육_중등_Y', #디지털성범죄_예방교육 경험이 있는 중학생
    'total_%': 'T_111', #디지털성범죄_예방교육 경험이 있는 청소년 전체
    }, inplace=True)

#소수점 둘째자리
digital_prevent_edu = digital_prevent_edu.round(2)

# %%
# 최종파일
digital_prevent_edu_final = digital_prevent_edu[['시도','T_110','T_111']]

# %% [markdown]
# #### 5-6) 성교육

# %%
#예방교육 도움정도 병합
SE_assist_df = pd.merge(edu_assist_6_MS,edu_assist_6_HS, on='시도', how='outer')
SE_assist_df = pd.merge(SE_assist_df, edu_assist1_6, on='시도', how='outer')

SE_assist_df.rename(columns={
    'high_A_6%': '성교육_도움정도_고등', #성교육 도움정도 고등학생
    'middle_A_6%': '성교육_도움정도_중등', #성교육 도움정도 중학생
    'total_A_6%': 'T_112' #성교육 도움정도 청소년 전체
    }, inplace=True)

# %%
#성교육
SE_prevent_edu = pd.merge(edu_exp_6_df, SE_assist_df, on='시도', how='outer')

#컬럼 최종
SE_prevent_edu.rename(columns={
    'high_%': '성교육_고등_Y', #성교육 경험 고등학생
    'middle_%': '성교육_중등_Y', #성교육 경험 중학생
    'total_%': 'T_113', #성교육 경험 청소년 전체
    }, inplace=True)

#소수점 둘째자리
SE_prevent_edu = SE_prevent_edu.round(2)

# %%
# 최종파일
SE_prevent_edu_final = SE_prevent_edu[['시도','T_112','T_113']]

# %% [markdown]
# #### 5-7) 성매매 예방 교육

# %%
#예방교육 도움정도 병합
prostitution_assist_df = pd.merge(edu_assist_7_MS,edu_assist_7_HS, on='시도', how='outer')
prostitution_assist_df = pd.merge(prostitution_assist_df, edu_assist1_7, on='시도', how='outer')

prostitution_assist_df.rename(columns={
    'high_A_7%': '성매매_도움정도_고등', #성매매 예방교육 도움정도 고등학생
    'middle_A_7%': '성매매_도움정도_중등', #성매매 예방교육 도움정도 중학생
    'total_A_7%': 'T_114' #성매매 예방교육 도움정도 청소년 전체
    }, inplace=True)

# %%
#성매매 예방 교육
prostitution_prevent_edu = pd.merge(edu_exp_7_df,prostitution_assist_df, on='시도', how='outer')

#컬럼 최종
prostitution_prevent_edu.rename(columns={
    'high_%': '성매매_예방교육_고등_Y', #성매매 예방교육 경험 있는 고등학생
    'middle_%': '성매매_예방교육_중등_Y', #성매매 예방교육 경험 있는 중학생
    'total_%': 'T_115', #성매매 예방교육 경험 있는 청소년 전체
    }, inplace=True)

#소수점 둘째자리
prostitution_prevent_edu  = prostitution_prevent_edu .round(2)

# %%
# 최종파일
prostitution_prevent_edu_final = prostitution_prevent_edu[['시도','T_114','T_115']]

# %% [markdown]
# #### 5-8) 성인매체 피해 예방교육

# %%
#예방교육 도움정도 병합
AM_assist_df = pd.merge(edu_assist_8_MS,edu_assist_8_HS, on='시도', how='outer')
AM_assist_df = pd.merge(AM_assist_df, edu_assist1_8, on='시도', how='outer')

AM_assist_df.rename(columns={
    'high_A_8%': '성인매체피해_도움정도_고등', #성인매채피해 예방교육 도움정도 고등학생
    'middle_A_8%': '성인매체피해_도움정도_중등', #성인매채피해 예방교육 도움정도 중학생
    'total_A_8%': 'T_116' #성인매채피해 예방교육 도움정도 청소년 전체
    }, inplace=True)

# %%
#성인매체 예방 교육
AM_prevent_edu = pd.merge(edu_exp_8_df,AM_assist_df, on='시도', how='outer')

#컬럼 최종
AM_prevent_edu.rename(columns={
    'high_%': '성인매체피해_예방교육_고등_Y', #성인매체피해 예방교육 경험 있는 고등학생
    'middle_%': '성인매체피해_예방교육_중등_Y', #성인매체피해 예방교육 경험 있는 중학생
    'total_%': 'T_117' #성인매체피해 예방교육 경험 있는 청소년 전체
    }, inplace=True)

#소수점 둘째자리
AM_prevent_edu = AM_prevent_edu.round(2)

# %%
# 최종파일
AM_prevent_edu_final = AM_prevent_edu[['시도','T_116','T_117']]

# %% [markdown]
# #### 5-9) 온라인 도박 피해 예방교육

# %%
#예방교육 도움정도 병합
gambling_assist_df = pd.merge(edu_assist_9_MS,edu_assist_9_HS, on='시도', how='outer')
gambling_assist_df = pd.merge(gambling_assist_df, edu_assist1_9, on='시도', how='outer')

gambling_assist_df.rename(columns={
    'high_A_9%': '온라인도박_도움정도_고등', #온라인도박 피해 예방교육 도움정도 고등학생
    'middle_A_9%': '온라인도박_도움정도_중등', #온라인도박 피해 예방교육 도움정도 중학생
    'total_A_9%': 'T_118' #온라인도박 피해 예방교육 도움정도 청소년 전체
    }, inplace=True)

# %%
#온라인도박 피해 예방 교육
gambling_prevent_edu = pd.merge(edu_exp_9_df,gambling_assist_df, on='시도', how='outer')

#컬럼 최종
gambling_prevent_edu.rename(columns={
    'high_%': '온라인도박_예방교육_고등_Y', #온라인도박 피해 예방교육 경험 있는 고등학생
    'middle_%': '온라인도박_예방교육_중등_Y', #온라인도박 피해 예방교육 경험 있는 중학생
    'total_%': 'T_119', #온라인도박 피해 예방교육 경험 있는 청소년 전체
    }, inplace=True)

#소수점 둘째자리
gambling_prevent_edu= gambling_prevent_edu.round(2)

# %%
# 최종파일
gambling_prevent_edu_final = gambling_prevent_edu[['시도','T_118','T_119']]

# %% [markdown]
# #### 5-10) 인터넷/스마트폰 이용교육

# %%
#예방교육 도움정도 병합
online_assist_df = pd.merge(edu_assist_10_MS,edu_assist_10_HS, on='시도', how='outer')
online_assist_df = pd.merge(online_assist_df, edu_assist1_10, on='시도', how='outer')

online_assist_df.rename(columns={
    'high_A_10%': '인터넷스마트폰_도움정도_고등', #인터넷/스마트폰 이용교육 도움정도 고등학생
    'middle_A_10%': '인터넷스마트폰_도움정도_중등', #인터넷/스마트폰 이용교육 도움정도 중학생
    'total_A_10%': 'T_120' #인터넷/스마트폰 이용교육 도움정도 청소년 전체
    }, inplace=True)

# %%
#인터넷/스마트폰 이용교육
online_prevent_edu = pd.merge(edu_exp_10_df,online_assist_df, on='시도', how='outer')

#컬럼 최종
online_prevent_edu.rename(columns={
    'high_%': '인터넷스마트폰_예방교육_고등_Y', #인터넷/스마트폰 이용교육 경험 있는 고등학생
    'middle_%': '인터넷스마트폰_예방교육_중등_Y', #인터넷/스마트폰 이용교육 경험 있는 중학생
    'total_%': 'T_121', #인터넷/스마트폰 이용교육 경험 있는 청소년 전체
    }, inplace=True)

#소수점 둘째자리
online_prevent_edu = online_prevent_edu.round(2)

# %%
# 최종파일
online_prevent_edu_final = online_prevent_edu[['시도','T_120','T_121']]

# %% [markdown]
# #### 5-11) 개인정보보호 교육

# %%
#예방교육 도움정도 병합
security_assist_df = pd.merge(edu_assist_11_MS,edu_assist_11_HS, on='시도', how='outer')
security_assist_df = pd.merge(security_assist_df, edu_assist1_11, on='시도', how='outer')

security_assist_df.rename(columns={
    'high_A_11%': '개인정보보호_도움정도_고등', #개인정보보호 교육 도움정도 고등학생
    'middle_A_11%': '개인정보보호_도움정도_중등', #개인정보보호 교육 도움정도 중학생
    'total_A_11%': 'T_122' #개인정보보호 교육 도움정도 청소년 전체
    }, inplace=True)

# %%
#개인정보보호교육
security_prevent_edu = pd.merge(edu_exp_11_df,security_assist_df, on='시도', how='outer')

#컬럼 최종
security_prevent_edu.rename(columns={
    'high_%': '개인정보보호교육_예방교육_고등_Y', #인터넷/스마트폰 이용교육 경험 있는 고등학생
    'middle_%': '개인정보보호교육_예방교육_중등_Y', #인터넷/스마트폰 이용교육 경험 있는 중학생
    'total_%': 'T_123', #인터넷/스마트폰 이용교육 경험 있는 청소년 전체
    }, inplace=True)

#소수점 둘째자리
security_prevent_edu = security_prevent_edu.round(2)

# %%
# 최종파일
security_prevent_edu_final = security_prevent_edu [['시도','T_122','T_123']]

# %% [markdown]
# # 안전교육 추가
# * 질병관리청 데이터

# %%
# !pip install openpyxl

# %%
# Change the sheet_name index to a valid value
data1 = pd.read_excel('/content/drive/MyDrive/Techit_dataton/데이터/청소년건강형태조사 2023_질병관리청_수정본/[손상안정] 청소년건강형태조사 2023_질병관리청.xlsx', sheet_name='7-5. 학교 안전교육 경험률')

# %%
df_1 = data1.iloc[15:33, -3:]
df_1['시도'] = data1.iloc[15:33, 2]

# %%
#안전교육 컬럼 분류
safety_prevent_edu= df_1.reset_index()[['시도', 'Unnamed: 58']]
safety_prevent_edu.rename(columns={'Unnamed: 58': 'T_126'}, inplace=True)
safety_prevent_edu.drop(index=0, inplace=True)
safety_prevent_edu

# 인덱스 재설정
safety_prevent_edu = safety_prevent_edu.reset_index(drop=True)

#타입 변경
safety_prevent_edu['T_126'] = safety_prevent_edu['T_126'].astype(float)
safety_prevent_edu['T_126_R'] = safety_prevent_edu['T_126'].rank(ascending=False)

# %%
# Out:
#       시도  T_126  T_126_R
# 0     서울   90.7      7.0
# 1     부산   90.9      6.0
# 2     대구   89.2     14.0
# 3     인천   92.3      2.5
# 4     광주   88.5     16.0
# 5     대전   91.1      5.0
# 6     울산   92.8      1.0
# 7     세종   87.2     17.0
# 8     경기   92.3      2.5
# 9     강원   90.5      8.0
# 10    충북   90.1      9.5
# 11    충남   89.0     15.0
# 12    전북   90.1      9.5
# 13    전남   89.9     11.0
# 14    경북   89.5     13.0
# 15    경남   92.0      4.0
# 16    제주   89.6     12.0

# %% [markdown]
# # 최종 결과(파일 합치기)

# %% [markdown]
# ### 1) 예방교육경험 Y/N 파일병합

# %%
from functools import reduce

# 예시 데이터프레임 리스트
dfs = [alcohol_prevent_edu_final, smoke_prevent_edu_final, violence_prevent_edu_final,
       sexual_prevent_edu_final, digital_prevent_edu_final, SE_prevent_edu_final,
       AM_prevent_edu_final, prostitution_prevent_edu_final, gambling_prevent_edu_final,
       online_prevent_edu_final, security_prevent_edu_final,safety_prevent_edu_final]

# '시도' 컬럼을 기준으로 모든 데이터프레임을 outer 결합
combined_df = reduce(lambda left, right: pd.merge(left, right, on='시도', how='outer'), dfs)
combined_df.head()
# Out:
#    시도  T_102  T_103  T_104  T_105  T_106  T_107  T_108  T_109  T_110  T_111  \
# 0  강원  59.92  68.06  62.45  87.07  65.62  92.21  65.62  88.21  65.20  84.22
# 1  경기  51.08  61.18  55.36  84.01  53.10  94.10  53.77  90.23  54.63  87.93
# 2  경남  58.07  57.90  63.23  89.79  58.38  95.66  61.36  94.13  60.73  90.21
# 3  경북  60.28  50.73  63.93  82.54  61.19  92.33  63.25  89.40  61.65  83.69
# 4  광주  51.29  54.15  58.05  87.17  57.12  93.21  56.89  89.06  55.49  85.47
#
#    T_112  T_113  T_116  T_117  T_114  T_115  T_118  T_119  T_120  T_121  \
# 0  64.77  84.60  51.27  54.37  67.09  60.46  61.19  66.16  56.33  70.53
# 1  53.10  82.45  45.14  57.42  54.07  66.98  52.79  49.79  44.47  83.02
# 2  59.63  88.39  49.93  58.04  59.01  70.49  56.19  62.24  51.02  80.98
# 3  62.79  84.50  52.29  54.65  63.25  62.32  59.83  54.49  53.89  69.82
# 4  54.09  82.26  46.86  51.89  55.26  68.30  51.29  57.55  46.63  73.58
#
#    T_122  T_123  T_126
# 0  60.13  61.22    NaN
# 1  52.67  74.14    NaN
# ...

# %% [markdown]
# ### 2) 순위 병합

# %%
# #음주교육
# alcohol_prevent_edu['T_102'] =  alcohol_prevent_edu['T_102'].rank(ascending=False)
# alcohol_prevent_edu['T_103'] = alcohol_prevent_edu['T_103'].rank(ascending=False)
# alcohol_prevent_edu_final_rank =  alcohol_prevent_edu[['시도','T_102','T_103']]

# #흡연
# smoke_prevent_edu['T_104'] =  smoke_prevent_edu['T_104'].rank(ascending=False)
# smoke_prevent_edu['T_105'] = smoke_prevent_edu['T_105'].rank(ascending=False)
# smoke_prevent_edu_final_rank =  smoke_prevent_edu[['시도','T_104','T_105']]

# #학교폭력
# violence_prevent_edu['T_106'] =  violence_prevent_edu['T_106'].rank(ascending=False)
# violence_prevent_edu['T_107'] = violence_prevent_edu['T_107'].rank(ascending=False)
# violence_prevent_edu_final_rank =  violence_prevent_edu[['시도','T_106','T_107']]

# #성폭력
# sexual_prevent_edu['T_108'] =  sexual_prevent_edu['T_108'].rank(ascending=False)
# sexual_prevent_edu['T_109'] = sexual_prevent_edu['T_109'].rank(ascending=False)
# sexual_prevent_edu_final_rank =  sexual_prevent_edu[['시도','T_108','T_109']]

# #디지털성범죄
# digital_prevent_edu['T_110'] =  digital_prevent_edu['T_110'].rank(ascending=False)
# digital_prevent_edu['T_111'] = digital_prevent_edu['T_111'].rank(ascending=False)
# digital_prevent_edu_final_rank =  digital_prevent_edu[['시도','T_110','T_111']]

#성교육
SE_prevent_edu['T_112'] =  SE_prevent_edu['T_112'].rank(ascending=False)
SE_prevent_edu['T_113'] = SE_prevent_edu['T_113'].rank(ascending=False)
SE_prevent_edu_final_rank =  SE_prevent_edu[['시도','T_112','T_113']]

#성매매
prostitution_prevent_edu['T_114'] =  prostitution_prevent_edu['T_114'].rank(ascending=False)
prostitution_prevent_edu['T_115'] = prostitution_prevent_edu['T_115'].rank(ascending=False)
prostitution_prevent_edu_final_rank =  prostitution_prevent_edu[['시도','T_114','T_115']]

#성인매체 피해
AM_prevent_edu['T_116'] =  AM_prevent_edu['T_116'].rank(ascending=False)
AM_prevent_edu['T_117'] = AM_prevent_edu['T_117'].rank(ascending=False)
AM_prevent_edu_final_rank =  AM_prevent_edu[['시도','T_116','T_117']]

#온라인 도박
gambling_prevent_edu['T_118'] =  gambling_prevent_edu['T_118'].rank(ascending=False)
gambling_prevent_edu['T_119'] = gambling_prevent_edu['T_119'].rank(ascending=False)
gambling_prevent_edu_final_rank = gambling_prevent_edu[['시도','T_118','T_119']]

#인터넷/스마트폰 이용교육
online_prevent_edu['T_120'] = online_prevent_edu['T_120'].rank(ascending=False)
online_prevent_edu['T_121'] = online_prevent_edu['T_121'].rank(ascending=False)
online_prevent_edu_final_rank =  online_prevent_edu[['시도','T_120','T_121']]

#개인정보보호
security_prevent_edu['T_122'] =  security_prevent_edu['T_122'].rank(ascending=False)
security_prevent_edu['T_123'] = security_prevent_edu['T_123'].rank(ascending=False)
security_prevent_edu_final_rank =  security_prevent_edu[['시도','T_122','T_123']]

# %%
# 예시 데이터프레임 리스트
# dfs_1 = [alcohol_prevent_edu_final_rank, smoke_prevent_edu_final_rank, violence_prevent_edu_final_rank,
#        sexual_prevent_edu_final_rank, digital_prevent_edu_final_rank, SE_prevent_edu_final_rank,
#        AM_prevent_edu_final_rank, prostitution_prevent_edu_final_rank, gambling_prevent_edu_final_rank,
#        online_prevent_edu_final_rank, security_prevent_edu_final_rank]

dfs_1 = [SE_prevent_edu_final_rank,AM_prevent_edu_final_rank, prostitution_prevent_edu_final_rank, gambling_prevent_edu_final_rank,
       online_prevent_edu_final_rank, security_prevent_edu_final_rank]

# '시도' 컬럼을 기준으로 모든 데이터프레임을 outer 결합
combined_dfs_1 = reduce(lambda left, right: pd.merge(left, right, on='시도', how='outer'), dfs_1)
combined_dfs_1
# Out:
#     시도  T_102  T_103  T_104  T_105  T_106  T_107  T_108  T_109  T_110  T_111  \
# 0   강원    6.0    2.0    7.0   10.0    2.0   15.0    2.0   14.0    3.0   14.0
# 1   경기   17.0    9.0   16.0   14.0   15.0   10.0   17.0   11.0   16.0    9.0
# 2   경남    9.0   10.0    4.0    3.0   10.0    4.0    8.0    4.0    9.0    4.0
# 3   경북    5.0   16.0    3.0   17.0    7.0   14.0    4.0   12.0    8.0   16.0
# 4   광주   16.0   15.0   14.0    9.0   12.0   12.0   14.0   13.0   15.0   11.0
# 5   대구    2.5    6.0    5.0    7.0    8.0   16.0    7.0    9.0    6.0    6.0
# 6   대전   12.0    8.0   10.0   13.0    9.0   11.0   13.0    6.0   11.0    7.0
# 7   부산    4.0   12.0    2.0    4.0    3.0    2.0    3.0    3.0    2.0    2.0
# 8   서울   14.0    7.0   17.0    8.0   16.0    9.0   15.0   10.0   17.0   10.0
# 9   세종   11.0   14.0   13.0   16.0   13.0   17.0   11.0   15.0   12.0   13.0
# 10  울산    8.0    4.0    6.0    2.0    4.0    7.0    5.0    1.0    4.0    1.0
# ...

# %% [markdown]
# #### 파일 저장

# %%
file_path = '/content/drive/MyDrive/Techit_dataton/데이터/preventive_education_final_1.xlsx'

# %%
with pd.ExcelWriter(file_path, engine='openpyxl') as writer:
    # Save combined_df to a sheet named 'preventive_percentage'
    combined_df.to_excel(writer, sheet_name='preventive_percentage', index=False)

    # Save combined_dfs_1 to a sheet named 'preventive_rank'
    combined_dfs_1.to_excel(writer, sheet_name='preventive_rank', index=False)
