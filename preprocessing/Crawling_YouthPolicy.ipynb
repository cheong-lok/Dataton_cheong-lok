# %% [markdown]
# #시나리오 1: 컬럼에 직접 해당하는 단어의 갯수만 카운트한다

# %%
pip install fitz
# Out:
# Collecting fitz
#   Downloading fitz-0.0.1.dev2-py2.py3-none-any.whl.metadata (816 bytes)
# Collecting configobj (from fitz)
#   Downloading configobj-5.0.8-py2.py3-none-any.whl.metadata (3.4 kB)
# Collecting configparser (from fitz)
#   Downloading configparser-6.0.1-py3-none-any.whl.metadata (10 kB)
# Collecting httplib2 (from fitz)
#   Downloading httplib2-0.22.0-py3-none-any.whl.metadata (2.6 kB)
# Collecting nibabel (from fitz)
#   Downloading nibabel-5.2.1-py3-none-any.whl.metadata (8.8 kB)
# Collecting nipype (from fitz)
#   Downloading nipype-1.8.6-py3-none-any.whl.metadata (6.6 kB)
# Requirement already satisfied: numpy in /Users/inda/anaconda3/lib/python3.11/site-packages (from fitz) (1.24.3)
# Requirement already satisfied: pandas in /Users/inda/anaconda3/lib/python3.11/site-packages (from fitz) (2.0.3)
# Collecting pyxnat (from fitz)
#   Downloading pyxnat-1.6.2-py3-none-any.whl.metadata (5.3 kB)
# Requirement already satisfied: scipy in /Users/inda/anaconda3/lib/python3.11/site-packages (from fitz) (1.11.1)
# Requirement already satisfied: six in /Users/inda/anaconda3/lib/python3.11/site-packages (from configobj->fitz) (1.16.0)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in /Users/inda/anaconda3/lib/python3.11/site-packages (from httplib2->fitz) (3.0.9)
# Requirement already satisfied: packaging>=17 in /Users/inda/anaconda3/lib/python3.11/site-packages (from nibabel->fitz) (23.1)
# Requirement already satisfied: click>=6.6.0 in /Users/inda/anaconda3/lib/python3.11/site-packages (from nipype->fitz) (8.0.4)
# Requirement already satisfied: networkx>=2.0 in /Users/inda/anaconda3/lib/python3.11/site-packages (from nipype->fitz) (3.1)
# Collecting prov>=1.5.2 (from nipype->fitz)
#   Downloading prov-2.0.0-py3-none-any.whl.metadata (3.7 kB)
# Collecting pydot>=1.2.3 (from nipype->fitz)
#   Downloading pydot-2.0.0-py3-none-any.whl.metadata (9.6 kB)
# Requirement already satisfied: python-dateutil>=2.2 in /Users/inda/anaconda3/lib/python3.11/site-packages (from nipype->fitz) (2.8.2)
# Collecting rdflib>=5.0.0 (from nipype->fitz)
#   Downloading rdflib-7.0.0-py3-none-any.whl.metadata (11 kB)
# Collecting simplejson>=3.8.0 (from nipype->fitz)
#   Downloading simplejson-3.19.2-cp311-cp311-macosx_11_0_arm64.whl.metadata (3.1 kB)
# Collecting traits!=5.0,<6.4,>=4.6 (from nipype->fitz)
#   Downloading traits-6.3.2.tar.gz (9.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.5/9.5 MB 5.1 MB/s eta 0:00:0000:0100:01
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: filelock>=3.0.0 in /Users/inda/anaconda3/lib/python3.11/site-packages (from nipype->fitz) (3.9.0)
# Collecting etelemetry>=0.2.0 (from nipype->fitz)
#   Downloading etelemetry-0.3.1-py3-none-any.whl.metadata (3.2 kB)
# Collecting looseversion (from nipype->fitz)
#   Downloading looseversion-1.3.0-py2.py3-none-any.whl.metadata (4.6 kB)
# Requirement already satisfied: pytz>=2020.1 in /Users/inda/anaconda3/lib/python3.11/site-packages (from pandas->fitz) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /Users/inda/anaconda3/lib/python3.11/site-packages (from pandas->fitz) (2023.3)
# Requirement already satisfied: lxml>=4.3 in /Users/inda/anaconda3/lib/python3.11/site-packages (from pyxnat->fitz) (4.9.3)
# Requirement already satisfied: requests>=2.20 in /Users/inda/anaconda3/lib/python3.11/site-packages (from pyxnat->fitz) (2.31.0)
# Requirement already satisfied: pathlib>=1.0 in /Users/inda/anaconda3/lib/python3.11/site-packages (from pyxnat->fitz) (1.0.1)
# Collecting ci-info>=0.2 (from etelemetry>=0.2.0->nipype->fitz)
#   Downloading ci_info-0.3.0-py3-none-any.whl.metadata (6.1 kB)
# Collecting isodate<0.7.0,>=0.6.0 (from rdflib>=5.0.0->nipype->fitz)
#   Downloading isodate-0.6.1-py2.py3-none-any.whl.metadata (9.6 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/inda/anaconda3/lib/python3.11/site-packages (from requests>=2.20->pyxnat->fitz) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/inda/anaconda3/lib/python3.11/site-packages (from requests>=2.20->pyxnat->fitz) (2.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/inda/anaconda3/lib/python3.11/site-packages (from requests>=2.20->pyxnat->fitz) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/inda/anaconda3/lib/python3.11/site-packages (from requests>=2.20->pyxnat->fitz) (2023.11.17)
# Downloading fitz-0.0.1.dev2-py2.py3-none-any.whl (20 kB)
# Downloading configobj-5.0.8-py2.py3-none-any.whl (36 kB)
# Downloading configparser-6.0.1-py3-none-any.whl (19 kB)
# Downloading httplib2-0.22.0-py3-none-any.whl (96 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 96.9/96.9 kB 4.3 MB/s eta 0:00:00
# Downloading nibabel-5.2.1-py3-none-any.whl (3.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 5.0 MB/s eta 0:00:0000:0100:01
# Downloading nipype-1.8.6-py3-none-any.whl (3.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 4.3 MB/s eta 0:00:00a 0:00:01
# Downloading pyxnat-1.6.2-py3-none-any.whl (95 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 95.6/95.6 kB 3.3 MB/s eta 0:00:00
# Downloading etelemetry-0.3.1-py3-none-any.whl (6.4 kB)
# Downloading prov-2.0.0-py3-none-any.whl (421 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 421.5/421.5 kB 4.1 MB/s eta 0:00:00a 0:00:01
# Downloading pydot-2.0.0-py3-none-any.whl (22 kB)
# Downloading rdflib-7.0.0-py3-none-any.whl (531 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 531.9/531.9 kB 2.7 MB/s eta 0:00:0000:0100:01
# Downloading simplejson-3.19.2-cp311-cp311-macosx_11_0_arm64.whl (74 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 74.5/74.5 kB 3.1 MB/s eta 0:00:00
# Downloading looseversion-1.3.0-py2.py3-none-any.whl (8.2 kB)
# Downloading ci_info-0.3.0-py3-none-any.whl (7.8 kB)
# Downloading isodate-0.6.1-py2.py3-none-any.whl (41 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.7/41.7 kB 3.8 MB/s eta 0:00:00
# Building wheels for collected packages: traits
#   Building wheel for traits (setup.py) ... done
#   Created wheel for traits: filename=traits-6.3.2-cp311-cp311-macosx_11_0_arm64.whl size=4999371 sha256=a75a515cc23ff03309baf466b6d7c0d149c44e28f0847052a11c473520dad888
#   Stored in directory: /Users/inda/Library/Caches/pip/wheels/eb/95/6e/3d5c21d6b340b7b64a86b7926293decf7f6991f67f914819ae
# Successfully built traits
# Installing collected packages: looseversion, traits, simplejson, pydot, nibabel, isodate, httplib2, configparser, configobj, ci-info, rdflib, pyxnat, etelemetry, prov, nipype, fitz
# Successfully installed ci-info-0.3.0 configobj-5.0.8 configparser-6.0.1 etelemetry-0.3.1 fitz-0.0.1.dev2 httplib2-0.22.0 isodate-0.6.1 looseversion-1.3.0 nibabel-5.2.1 nipype-1.8.6 prov-2.0.0 pydot-2.0.0 pyxnat-1.6.2 rdflib-7.0.0 simplejson-3.19.2 traits-6.3.2
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install PyMuPDF
# Out:
# Collecting PyMuPDF
#   Downloading PyMuPDF-1.24.1-cp311-none-macosx_11_0_arm64.whl.metadata (3.4 kB)
# Collecting PyMuPDFb==1.24.1 (from PyMuPDF)
#   Downloading PyMuPDFb-1.24.1-py3-none-macosx_11_0_arm64.whl.metadata (1.4 kB)
# Downloading PyMuPDF-1.24.1-cp311-none-macosx_11_0_arm64.whl (3.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 5.6 MB/s eta 0:00:0000:0100:01
# Downloading PyMuPDFb-1.24.1-py3-none-macosx_11_0_arm64.whl (29.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 29.5/29.5 MB 4.3 MB/s eta 0:00:0000:0100:01
# Installing collected packages: PyMuPDFb, PyMuPDF
# Successfully installed PyMuPDF-1.24.1 PyMuPDFb-1.24.1
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install tabula-py
# Out:
# Collecting tabula-py
#   Downloading tabula_py-2.9.0-py3-none-any.whl.metadata (7.5 kB)
# Requirement already satisfied: pandas>=0.25.3 in /Users/inda/anaconda3/lib/python3.11/site-packages (from tabula-py) (2.0.3)
# Requirement already satisfied: numpy in /Users/inda/anaconda3/lib/python3.11/site-packages (from tabula-py) (1.24.3)
# Collecting distro (from tabula-py)
#   Downloading distro-1.9.0-py3-none-any.whl.metadata (6.8 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/inda/anaconda3/lib/python3.11/site-packages (from pandas>=0.25.3->tabula-py) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/inda/anaconda3/lib/python3.11/site-packages (from pandas>=0.25.3->tabula-py) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /Users/inda/anaconda3/lib/python3.11/site-packages (from pandas>=0.25.3->tabula-py) (2023.3)
# Requirement already satisfied: six>=1.5 in /Users/inda/anaconda3/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas>=0.25.3->tabula-py) (1.16.0)
# Downloading tabula_py-2.9.0-py3-none-any.whl (12.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.0/12.0 MB 3.9 MB/s eta 0:00:0000:0100:01
# Downloading distro-1.9.0-py3-none-any.whl (20 kB)
# Installing collected packages: distro, tabula-py
# Successfully installed distro-1.9.0 tabula-py-2.9.0
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install jpype1
# Out:
# Collecting jpype1
#   Downloading JPype1-1.5.0-cp311-cp311-macosx_10_9_universal2.whl.metadata (4.9 kB)
# Requirement already satisfied: packaging in /Users/inda/anaconda3/lib/python3.11/site-packages (from jpype1) (23.1)
# Downloading JPype1-1.5.0-cp311-cp311-macosx_10_9_universal2.whl (587 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 587.4/587.4 kB 5.0 MB/s eta 0:00:0000:0100:01
# Installing collected packages: jpype1
# Successfully installed jpype1-1.5.0
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ### pdf 파일 텍스트 읽어오기

# %%
import fitz

# %%
# path = "./(1권) 2024년 청소년사업 안내_1.30.pdf"
# path = "./(2권) 2024년 청소년사업 안내_1.30.pdf"
# path = "./2024년+학생건강증진+분야+주요업무+추진방향.pdf"
# path = "./2023년 학생건강증진 분야 주요업무 추진방향 230111.pdf"
# path = "./제19차(2023)+청소년건강행태조사+결과발표회+자료집_최종 (1).pdf" -> 주요내용 모두 표로 이뤄져 무의미
# path = "./231228_김현숙_여성가족부_장관_2024년_신년사_최종배포본.pdf" -> 청소년이 메인이 아님, 기각
path = "./[3.28.목.행사시작(14시)이후] 2023년 학생 건강검사 표본통계 및 청소년건강행태조사 결과 발표 (1).pdf"

doc = fitz.open(path)

text = ""
for page in doc:
    text += page.get_text()

print(text)

# Save text to a text file
with open('./[3.28.목.행사시작(14시)이후] 2023년 학생 건강검사 표본통계 및 청소년건강행태조사 결과 발표 (1).txt', 'w', encoding='utf-8') as file:
    file.write(text)
# Out:
#
# - 1 -
# 광부
# 보도자료
# 보도시점
# 2024. 3. 28.(목) 행사시작(14:00) 이후
# 배포
# 2024. 3. 28.(목) 08:00
# 2023년 학생 건강검사 표본통계 및
# 청소년건강행태조사 결과 발표
#  - 학생 건강검사 결과, 비만 등 각종 건강지표 전반적으로 개선
#  - 청소년건강행태조사 결과, 음주, 신체활동은 개선되고 있으나 식생활 지표는 개선 필요
#   교육부(부총리 겸 장관 이주호)와 질병관리청(청장 지영미)은 2023년에 실시한
# ‘학생 건강검사 표본통계’와 ‘청소년건강행태조사*’ 결과를 3월 28일(목)에
# 공동으로 발표한다.
# * 제19차(2023년) 청소년건강행태조사결과발표회개최(3.28.(목), 질병관리청)
#   학생 건강검사(교육부 주관)는 전국 초․중․고등학교 중 표본으로 선정된
# 1,009개교*에서 실시한 신체발달 상황, 건강검진 결과에 대해 분석한 자료이며,
# 청소년건강행태조사(질병관리청 주관)는 전국 800개 표본학교의 중·고등학생 약
# 6만 명을 대상**으로 흡연, 음주, 신체활동 등 건강행태 현황을 파악한 자료이다.
# * 초‧중‧고표본학교의전학년(87,182명)에대한신체발달상황및초1‧4학년
# 및중‧고1학년(30,516명)에대한건강검진결과분석
# ** 2023년조사참여율: 92.9%(56,935명중52,880명참여)
#   이번에 발표하는 통계자료는 우리나라 학생들의 건강상태 및 행태에 대한
# 자료로 향후 학생 건강증진 정책의 기초자료로 활용된다.
# <학생건강검사및청소년건강행태조사개요>
#
# 구분
# 학생 건강검사
# 청소년건강행태조사
# 대상
# · 전국 초‧중‧고교 학생 87,000여명
# · 전국 중‧고교 학생 60,000여명
# 조사항목
# 및 방법
# · 신체발달 : 학교 자체
# · 건강검진 : 병ㆍ의원 등 검진기관
# · 흡연ㆍ음주, 신체활동, 식생활 등
# 건강행태 : 자기기입식 온라인 조사
#
#
# - 2 -
# 1
#  학생 건강검사(2023년) 표본통계 주요 결과
# [신체 발달]
#   학생들의 성장 수준을 확인하기 위해 초등학교 1학년부터 고등학교 3학년
# 학생을 대상으로 건강검사를 실시하였으며, 신체 발달(키, 몸무게, 비만도) 상황은
# 다음과 같다.
#   우선 키 발달 상황을 보면, 초등학교 6학년 남학생은 153.3cm, 여학생은 153.2cm,
# 중학교 3학년 남학생은 170.9cm, 여학생은 160.9cm, 고등학교 3학년 남학생은
# 174.4cm, 여학생은 161.7cm로 최근 2년(’21년~’22년) 발달 정도와 유사하였다.
# <최근 3년간 키 발달 상황>
# (단위: cm)
# 학년
# 남학생
# 여학생
# ’21
# ’22
# ’23
# 연도별차이
# ’21
# ’22
# ’23
# 연도별차이
# ’23-’22
# ’23-’21
# ’23-’22
# ’23-’21
# 초등학교6학년
# 153.6
# 153.7
# 153.3
# -0.4
# -0.3
# 153.2
# 153.5
# 153.2
# -0.3
# -
# 중학교3학년
# 170.8
# 169.6
# 170.9
# 1.3
# 0.1
# 160.7
# 160.6
# 160.9
# 0.3
# 0.2
# 고등학교3학년
# 174.1
# 174.5
# 174.4
# -0.1
# 0.3
# 161.6
# 161.9
# 161.7
# -0.2
# 0.1
# <최근 5년간 키 증감 추이(cm)>
# <남학생>
# <여학생>
# ※ 2020년은코로나19 확산으로인해건강검사실시유예로미실시(이하항목동일)
#   최근 3년(’21년 대비 ’23년 분석 결과) 간 몸무게 증감 현황을 보면 초등학교
# 6학년 남학생은 50.6kg, 여학생은 47.0kg으로 각각 1.5kg과 0.6kg이
# 감소하였다.
#   중학교 3학년 남학생은 66.3kg, 여학생은 55.1kg으로 각각 1.2kg과 0.2kg
# 감소하였다. 고등학교 3학년 남학생은 72.7kg으로 1.2kg 증가하였으며,
# 여학생은 58.2kg으로 동일하였다.
#
# - 3 -
# <최근 3년간 몸무게 증감 현황>
# (단위: kg)
# <최근 5년간 몸무게 증감 추이(kg) >
# <남학생>
# <여학생>
#   과체중+비만 학생의 비율은 29.6%로 최근 2년 연속 감소 추세에 있으며,
# 읍․면 지역의 과체중+비만 학생 비율은 34.4%로 도시 지역 학생 비율인
# 28.7%보다 상대적으로 5.7%p가 컸다.
# <최근 3년간 비만군(과체중+비만) 학생 비율 증감 현황 >
# 구분
# 과체중비율(%)
# 비만비율(%)
# 비만군(과체중+비만)
# (%)
# 비만군(과체중+비만)
# 연도간차이(%p)
# ’21
# ’22
# ’23
# ’21
# ’22
# ’23
# ’21
# ’22
# ’23
# ’23-’22
# ’23-’21
# 합계
# 11.8
# 11.8
# 11.2
# 19.0
# 18.7
# 18.4
# 30.8
# 30.5
# 29.6
# -0.9
# -1.2
# 초등학교전학년
# 12.7
# 12.1
# 12.0
# 18.7
# 17.7
# 18.3
# 31.4
# 29.8
# 30.3
# 0.5
# -1.1
# 중학교전학년
# 11.6
# 11.1
# 10.5
# 19.1
# 21.7
# 17.7
# 30.7
# 32.8
# 28.1
# -4.7
# -2.6
# 고등학교전학년
# 10.3
# 11.7
# 10.3
# 19.5
# 18.3
# 19.6
# 29.8
# 30.0
# 29.9
# -0.1
# 0.1
# * 시
# 도
# 별비
# 만
# 군학
# 생현
# 황
# (%) : 전
# 남
# (37.1)>제
# 주
# (35.4)>경
# 북
# (34.7)...>서
# 울
# (27.3)>경
# 기
# (26.8)>세
# 종
# (25.6)
# ※ 2017년소아청소년성장도표기준(연령별체질량지수) 적용(비만: 95백분위수
# 이상과체중: 85백분위수이상～95백분위수미만)
# <최근 5년간 이상 체중 비율 증감 추이(%)>
# 학년
# 남학생
# 여학생
# ’21
# ’22
# ’23
# 연도별차이
# ’21
# ’22
# ’23
# 연도별차이
# ’23-’22
# ’23-’21
# ’23-’22
# ’23-’21
# 초등학교6학년
# 52.1
# 51.6
# 50.6
# -1.0
# -1.5
# 47.6
# 47.2
# 47.0
# -0.2
# -0.6
# 중학교3학년
# 67.5
# 64.6
# 66.3
# 1.7
# -1.2
# 55.3
# 55.6
# 55.1
# -0.5
# -0.2
# 고등학교3학년
# 71.5
# 71.8
# 72.7
# 0.9
# 1.2
# 58.2
# 57.5
# 58.2
# 0.7
# -
#
# - 4 -
# <2023년 지역별 체질량지수(BMI) 기준 비만군(과체중+비만) 학생 비율 현황>
# 구분
# 전국평균
# 도시지역(a)
# 읍･면지역(b)
# 차이(b-a)
# 합계
# 29.6%
# 28.7%
# 34.4%
# 5.7%p
# 초등학교
# 30.3%
# 29.3%
# 35.0%
# 5.7%p
# 중학교
# 28.1%
# 27.1%
# 34.0%
# 6.9%p
# 고등학교
# 29.9%
# 29.2%
# 33.5%
# 4.3%p
# ※ 학교 소재지 기준으로 특별‧광역‧중‧소도시는 도시 지역 / 나머지는 읍‧면 지역으로 구분
#    ‣ 최
# 근
#  5년
# 간
#  지
# 역
# 별
#  비
# 만
# 군
#  학
# 생
#  비
# 율
#  격
# 차
# (읍
# 면
# 지
# 역
# -도
# 시
# 지
# 역
# , %
# p) : (`19)2.0→
# (`21)3.4→
# (`22)3.1→
# (`23)5.7
# [건강 검진]
#   학생들의 건강상태를 확인하기 위해 실시하는 건강검진은 초등학교 1·4학년,
# 중학교 1학년, 고등학교 1학년을 대상으로 실시하며, 구강, 눈, 병리검사(소변,
# 혈액, 결핵, 혈압) 등 10개 영역에 걸쳐 실시되었다.
#   시력 이상* 학생의 비율은 56.0%로 2022년 대비 0.8%p 증가하였으며, 소변
# 검사 결과 단백뇨 및 혈뇨(잠혈) 증상이 있는 학생의 비율은 0.3%로 2022년과
# 유사하였다.
# * 시
# 력
# 검
# 사완
# 료
# 자중안
# 경등
# 으
# 로교
# 정중
# 이
# 거
# 나
# , 나
# 안
# 시
# 력
# 이좌
# ‧우어
# 느한
# 쪽
# 이0.7 이
# 하
# 인경
# 우
# ※ 시도별현황
# ‣ (시력이상비율,%) : 대전(60.9)>서울(60.1)>제주(59.9)...세종(52.6)>충남(51.3)>전남(50.5)
# ‣ (소변검사이상비율,%) : 인천(1.00)>경북(0.61)>대전(0.41)...충북(0.04)>대구(0.04)>광주(0.00)
#   <최근 3년간 시력이상 및 혈뇨(잠혈) 학생 비율 현황>
# 구
# 분
# 시력이상비율(%)
# 시력이상비율
# 연도간차이(%p)
# 소변검사이상비율(%)
# 소변검사이상
# 연도간차이(%p)
# ’22
# ’23
# ’23-’22
# ’22
# ’23
# ’23-’22
# 합계
# 55.2
# 56.0
# 0.8
# 0.29
# 0.30
# 0.10
# 초등학교1학년
# 27.5
# 29.6
# 2.1
# 0.02
# 0.04
# 0.02
# 초등학교4학년
# 54.5
# 51.9
# -2.6
# 0.12
# 0.20
# 0.08
# 중학교1학년
# 65.2
# 68.0
# 2.8
# 0.48
# 0.52
# 0.04
# 고등학교1학년
# 73.0
# 75.3
# 2.3
# 0.74
# 0.45
# -0.29
# <최근 5년간 시력 및 소변검사 이상 비율 증감 추이(%)>
# <시력 이상 비율>
# <소변검사 이상 비율>
#
# - 5 -
#   질병의 조기 발견 및 치료를 위하여 과체중 및 비만 판정을 받은 학생을
# 대상으로 신규로 도입(’21년 최초검사)한 혈액검사 결과, 총콜레스테롤 이상 학생
# 비율은 7.9%p, 중성지방(TG) 이상은 2.7%p, 저밀도지단백(LDL) 콜레스테롤
# 이상은 7.4%p 각각 감소한 반면, 고밀도지단백(HDL) 콜레스테롤 이상 학생
# 비율은 3.9%p 증가하였다.
# ※ 시도별현황
# ‣ (TG 이상비율,%) : 경남(38.3)>울산(36.0)>전남(34.8)...제주(19.6)>세종(15.7)>충남(14.5)
# ‣ (LDL-C 이상비율,%) : 전남(17.3)>대전(17.0)>부산(15.9)...경북(7.3)>대구(6.6)>세종(4.0)
# 구분
# 총콜레스테롤이상(상승) 비율중성지방이상비율
# LDL-C 이상비율
# HDL-C 이상비율
# 2022년
# 23.9%
# 30.1%
# 19.9%
# 10.8%
# 2023년
# 16.0%
# 27.4%
# 12.5%
# 14.7%
# 증감
# -7.9%p
# -2.7%p
# -7.4%p
# 3.9%p
# < 과체중 및 비만 학생 대상 혈액검사 결과>
#
# - 6 -
# 2
#  청소년건강행태조사(2023년) 주요 결과
# [흡연‧음주]
#   2023년 청소년(중1~고3)의 흡연‧음주 행태는 2022년에 비해 개선되었다.
#   현재 흡연율(일반담배(궐련))은 2023년 결과 남학생 5.6%, 여학생 2.7%로 2022년에
# 비해 남학생은 감소(0.6%p↓)하였으며, 전자담배* 현재 사용률도 유사한 경향이었다.
# * (액상형) 남4.5%→3.8%, 여2.2%→2.4%, (궐련형) 남3.2%→2.7%, 여1.3%→1.4%
#   일반담배, 전자담배 중 하나라도 사용한 담배제품 현재사용률*은 2023년
# 남학생 6.6%, 여학생 3.5%로 2022년 결과(남 7.3%, 여 3.4%)에 비해 남학생은
# 감소하였으나 여학생은 큰 차이 없었다.
# * 시도별현황: 제주(7.4%)>전남(6.8%)>전북(6.6%)...서울‧부산‧대구(4.4%)>세종(3.7%)
#
# * 자료원: 청소년건강행태조사
# * 담배제품현재사용률: 최근30일동안일반담배(궐련) 또는궐련형전자담배또는액상형전자담배를
# 1일이상사용한사람의분율
# * 현재흡연율(일반담배(궐련)) : (~’18년) 최근30일동안1일이상흡연한사람의분율; (’19년～) 최근30일
# 동안1일이상일반담배(궐련)를흡연한사람의분율
# * 액상형전자담배현재사용률: 최근30일동안1일이상액상형전자담배를사용한사람의분율
# * 궐련형전자담배현재사용률: 최근30일동안1일이상궐련형전자담배를사용한사람의분율
#   현재 음주율*은 남학생 13.0%, 여학생 9.0%로 2022년 대비 감소(남 2.0%p↓,
# 여 1.9%p↓)하였으며, 1회 평균 음주량이 중등도(남자 소주 5잔, 여자 3잔) 이상인
# 위험 음주율도 남녀학생 모두 감소(남 6.1%→5.4%, 여 5.1%→4.5%)하였다.
# * 시도별현황: 강원(14.2%)>충북‧경북(13.2%)...부산(9.5%)>서울(9.4%)>세종(8.3%)
#
# - 7 -
#   반면, 현재 음주자 중 위험음주율은 남학생 41.3%, 여학생 50.1%로 2022년
# 대비 증가(남 0.9%p↑, 여 3.5%p↑)하였으며, 특히 중학생(남 21.6%→24.7%, 여 38.5%
# →44.6%)에서 크게 증가하였다.
# * 자료원: 청소년건강행태조사
# * 현재음주율: 최근30일동안1잔이상술을마신적이있는사람의분율
# * 위험음주율: 최근30일동안1회평균음주량이중등도이상(남자소주5잔이상, 여자소주3잔
# 이상)인사람의분율
# [신체활동‧식생활]
#   신체활동은 지속 증가하여 개선되고 있으나, 식생활 지표는 개선되지 않았다.
#   하루 60분 주5일 이상 신체활동 실천율*은 2023년 남학생 24.6%, 여학생
# 9.2%로 2022년 대비 남녀학생 모두 증가(남 1.2%p↑, 여 0.4%p↑)하였다.
# * 시도별현황: 충북(19.4%)>제주(19.2%)>울산(19.1%)...광주(15.8%)>세종(15.3%)>전남(14.5%)
#   고강도 신체활동 실천율(주3일 이상)은 남학생 52.1%, 여학생 29.6%로 2022년
# 대비 큰 폭으로 증가(남 4.8%p↑, 여 3.3%p↑)하였으며, 근력강화운동 실천율(주3일
# 이상)도 2023년 결과 남녀 학생 모두 증가(남 37.7%→38.5%, 여 10.1%→11.7%)하였다.
#   주중 학습목적으로 앉아서 보낸 하루 평균 시간은 2022년에 비해 소폭 감소
# (460분→455분)하였으나, 학습목적 이외 앉아서 보낸 하루 평균 시간은 증가(주중
# 187분→206분, 주말 298분→322분)한 것으로 나타났다.
#
# - 8 -
#   * 자료원: 청소년건강행태조사
# * 하루60분주5일이상신체활동실천율: 최근7일동안운동종류상관없이심장박동이평상시보다
# 증가하거나, 숨이찬정도의신체활동을하루에총합이60분이상한날이5일이상인사람의분율
# * 주3일이상근력강화운동실천율: 최근7일동안근력강화운동(팔굽혀펴기, 윗몸일으키기, 역기들기,
# 아령, 철봉, 평행봉등)을3일이상한사람의분율
#   아침식사 결식률*(주5일 이상)은 2023년 남학생 39.7%, 여학생 42.6%로
# 2022년에 비해 남녀 학생 모두 증가(남 2.3%p↑, 여 1.9%p↑)하였고, 패스트푸드
# 섭취율(주3회 이상)은 남학생 29.2%, 여학생 24.4%로 전년 대비 남학생은
# 증가(0.2%p↑)하였으나 여학생은 감소(1.1%p↓) 하였다.
# * 시도별현황: 인천(43.7%)>충남‧전북(43.6%)...부산(39.8%)>울산(38.1%)>경남(38.0%)
#   과일 섭취율(일1회 이상)은 남학생 16.3%, 여학생 15.7%로 전년 대비 감소(남
# 1.2%p↓, 여 1.3%p↓) 경향이 지속되었다.
#
# * 자료원: 청소년건강행태조사
# * 주5일이상아침식사결식률: 최근7일동안아침식사를5일이상먹지않은사람의분율
# * 일1회이상과일섭취율: 최근7일동안1일1회이상과일(과일주스제외)을먹은사람의분율
#
# - 9 -
#   음료섭취율의 경우, 탄산‧에너지‧이온‧과즙‧커피음료, 가당우유 등 단맛이 나는
# 음료를 모두 포함한 단맛음료 섭취율*(주3회 이상)은 2023년 남학생 69.4%,
# 여학생 60.0%로 2022년에 비해 소폭 증가(남 2.0%p↑, 여 0.4%p↑)하였다.
# * 시도별현황: 전남(68.3%)>경북(67.3%)>충북(66.5%)...대구(62.8%)>강원(62.3%)>세종(61.7%)
#
# [정신건강]
#   청소년의 정신건강 지표는 2023년 다시 개선된 것으로 나타났다.
#   우
# 울
# 감
#  경
# 험
# 률
# *은
#  2023년
#  남
# 학
# 생
#  21.4%
# , 여
# 학
# 생
#  30.9%
# 로
#  2022년
# 에
#  비
# 해
#  감
# 소
# (남
#  2.8%
# p↓
# ,
# 여
#  2.6%
# p↓
# )하
# 였
# 고
# , 특
# 히
#  고
# 등
# 학
# 생
# (남
#  25.3%
# →
# 21.4%
# , 여
#  33.6%
# →
# 30.2%
# )에
# 서
#  큰
#  폭
# 으
# 로
#  감
# 소
# 하
# 였
# 다
# .
# * 시도별현황: 전북(28.6%)>서울(27.5%)>경기(27.1%)...전남(24.2%)>경남(22.7%)>부산(21.5%)
#   스트레스 인지율도 남녀 학생 모두 감소(남 36.0%→30.8%, 여 47.0%→44.2%)하였으며,
# 스트레스 원인으로는 성적․진로에 대한 부담(36.1%), 학업(25.9%), 외모(10.2%),
# 부모님과의 갈등(9.4%) 순으로 나타났다.
#   주중 스마트폰 사용시간은 2023년 남학생 266분, 여학생 294분으로 2022년
# 대비 남학생은 증가(8분↑)하였으나, 여학생은 감소(6분↓)하였다. 3년마다 조사
# 중인 스마트폰 과의존 경험률(총 40점 중 23점 이상)은 2023년 남학생 24.0%,
# 여학생 32.3%로 2020년 대비 증가(남 2.8%p↑, 여 2.3%p↑)한 것으로 나타났다.
# * 자료원: 청소년건강행태조사
# * 우울감경험률: 최근12개월동안2주내내일상생활을중단할정도로슬프거나절망감을느낀
# 적이있는사람의분율
# * 스트레스인지율: 평상시스트레스를‘대단히많이’ 또는‘많이’ 느끼는사람의분율
#
# - 10 -
# 3
#  주요 조사결과 진단
#   2023년 학생 건강검사 및 청소년건강행태조사 결과에서도 확인할 수 있듯이
# 전반적인 건강행태가 전년도에 비해 나아졌으나, 식생활은 개선이 필요한 것으로
# 확인되었다.
#   이번 조사결과에 대해 이주호 부총리 겸 교육부장관은 “그동안 우리 학생들의
# 건강관리 중요성이 강조되면서 학교를 중심으로 신체활동 기회를 확대하는 등
# 다양한 지원이 이뤄진 결과 과체중과 비만학생의 비율이 감소하는 등 각종
# 건강지표가 개선되고 있는 경향을 확인할 수 있었으나, 일부 지표는 여전히
# 시도 간 차이가 있었다”라고 하면서,
#   “앞으로, 교육부는 관계부처 및 시도교육청과 적극 협력하여 건강증진교육을
# 강화하고, 예방효과가 큰 건강증진 프로그램을 적극적으로 지원하는 등 『제2차
# 학생건강증진기본계획(2024~2028)』을 내실있게 추진하여 학생 한명 한명이
# 건강하게 성장하고 학습할 수 있도록 최선의 노력을 다하겠다.”라고 밝혔다.
#   지영미 질병관리청장은 “2023년은 코로나19 위기단계가 하향되고 온전한
# 일상을 회복하면서 청소년의 신체활동은 3년간 지속 개선 경향을 보였고, 식생활
# 지표는 여전히 개선이 필요한 것으로 나타났다.”라고 밝히며,
#   “음주와 정신건강 지표는 전년보다 다소 개선되었으나, 일부 지표는 성별,
# 학교급별 경향 차이가 있어 지속적인 현황 파악이 필요하다.”라고 밝혔다.
#   아울러, “오늘 발표회에서 청소년의 식생활 및 정신건강과 관련한 관계 분야
# 전문가의 발표와 토론을 통해 개선 방안을 모색하는 심도 있는 논의가 이뤄질
# 것으로 기대된다.”라고 전하며,
#   “앞으로도 질병청은 변화하는 사회환경에 대비하여 청소년의 최신 건강문제를
# 파악하고 관련 요인을 확인하는 등 조사 체계 개선과 심층분석을 지속하며,
# 청소년의 건강증진을 위해 관계부처와 적극 협력해 나가겠다.”라고 밝혔다.
#
#   2023년 학생 건강검사 표본통계 분석 결과 보고서는 교육부 학생건강정보센터*,
# 제19차(2023년) 청소년건강행태조사 상세 보고서는 질병관리청 청소년건강행태조사
# **
# 누리집에 공개된다.
# * (http://www.schoolhealth.kr),
# ** (http://www.kdca.go.kr/yhs/)
#
# - 11 -
# <붙임>
# 1. 학생건강검사및청소년건강행태조사개요
# 2. 제19차(2023) 청소년건강행태조사결과발표회일정
# 3. 제2차학생건강증진기본계획(2024~2028) 추진방향및정책과제
# <별첨>
# 1. 2023년학생건강검사주요결과
# 2. 2023년청소년건강행태조사주요결과
# 담당 부서
# 교육부
# 학생건강정책관
# 책임자
# 과  장
# 김진형(044-203-6877)
# 학생건강검사결과
# 학생건강정책과
# 담당자
# 사무관
# 김태환(044-203-6547)
# 담당 부서
# 질병관리청
# 만성질환관리국
# 책임자
# 과  장
# 오경원(043-719-7460)
# 청소년건강행태조사결과
# 건강영양조사분석과
# 담당자
# 연구관
# 최선혜(043-719-7461)
#
# - 12 -
# 붙임 1
# 붙임 1
#  학생 건강검사 및 청소년건강행태조사 개요
# ① 학생 건강검사 표본조사
#  ○ 작성목적 : 신체발달상황, 질병이환 등 학생건강 실태분석을 통한 체계적이고
# 신뢰성 있는 학생건강지표 생성으로 과학적 근거기반의
# 학생건강증진정책 수립ㆍ추진
#  ○ 법적근거 : 「학교보건법」제7조 및「학교건강검사규칙」제11조
#  ○ 분석대상 : 전국 초․중․고등학교 1,009개교, 87,182명
#    - 신체발달 상황 : 초․중․고등학교 전학년 중 87,182명
#    - 건강조사 : 초․중․고등학교 전학년 중 84,798명
#    - 건강검진 : 초1･4학년, 중･고 1학년 중 30,516명
#  ○ 건강검사 기간 : '23. 3 ~ 9월(7개월)
#  ○ 건강검사 항목
#    - 신체발달상황(3개 영역) : 키, 몸무게, 비만율
#    - 건강조사(9개 영역) : 영양섭취‧식습관, 신체활동, 수면, 개인위생, 안전,
# 음주‧흡연, 가정 및 학교생활, 심리정서, TV시청‧인터넷 사용
#    - 건강검진(10개 영역) : 척추, 눈(시력‧안질환), 귀(청력‧귓병), 콧병, 목병, 피부병,
# 구강(치아상태, 구강상태), 병리검사(소변, 혈액, 결핵, 혈압), 허리둘레, 그 밖의
# 사항(의사 판단 항목 추가)
#  ○ 검사기관
#    - 신체발달 상황 및 건강조사 : 학교(담당교사)
#    - 건강검진 : 병･의원 등 검진기관
#
# - 13 -
# ② 청소년건강행태조사
# □ 사업목적
#  ○ 우리나라 청소년의 건강행태 현황 파악
#  ○ 청소년 건강행태 국내･외 모니터링 지표 산출
#     * 국민건강증진종합계획, 학교보건 사업 및 정책, WHO 만성질환 예방 및 관리 지표로 활용
# □ 추진경과
#  ○ ｢국가 만성병 감시체계 구축 계획｣ 일환으로 2005년 도입, 매년 실시
#  ○ 대표성 확보, 시의적절한 결과 활용을 위해 표본설계 매년 실시(’11년~),
# 조사 시기 변경(9월→6월, ’12년~) 및 조사명(청소년건강행태온라인조사 →
# 청소년건강행태조사, ’18년~) 변경
# □ 조사내용
#  ○ 조사대상: 중1~고3 학생 약 6만 명(17개 시·도, 800개 학교)
#     * 시
# ‧도
#  단
# 위
#  통
# 계
# 산
# 출
# 을
#  위
# 해
#  학
# 교
# 급
# 을
#  고
# 려
# 한
#  800개
# 교
# (모
# 집
# 단
#  학
# 교
#  수
# 의
#  약
# 15%) 추
# 출
#  ○ 조사방법: 익명성 자기기입식 온라인조사
#     * 학
# 교
#  수
# 업
# 시
# 간
#  내
#  조
# 사
# 지
# 원
#  담
# 당
# 교
# 사
#  감
# 독
#  하
# 에
#  모
# 바
# 일
# 기
# 기
# (태
# 블
# 릿
# PC, 스
# 마
# 트
# 폰
#  등
# ) 활
# 용
#  조
# 사
#  ○ 조사시기: 6-7월(’20~’23년 코로나19 유행으로 8-10월 실시)
#  ○ 조사내용: 15개 영역*, 약 120개 문항, 약 110개 지표 산출
#     * 흡
# 연
# , 음
# 주
# , 신
# 체
# 활
# 동
# , 식
# 생
# 활
# , 비
# 만
#  및
#  체
# 중
# 조
# 절
# , 정
# 신
# 건
# 강
# , 손
# 상
#  및
#  안
# 전
# 의
# 식
# , 구
# 강
# 건
# 강
# , 개
# 인
# 위
# 생
# ,
# 성행태, 아토피･천식, 약물, 인터넷 중독, 건강형평성, 폭력
#    ※ ’18년 이후 순환조사체계 운영(필수문항: 매년, 순환문항: 3년 주기, 선택문항: 필요 시 조사)
#       → ’23년 순환조사 영역: 정신건강, 약물, 인터넷중독, 아토피‧천식
#
# - 14 -
# 붙임 2
# 붙임 2
#  제19차(2023) 청소년건강행태조사 결과발표회 일정
#
# - 15 -
# 붙임 3
# 붙임 3
#  제2차 학생건강증진 기본계획(2024~2028) 추진 방향 및 정책과제
# 정책영역
# 정책과제
# 학교체육 활성화
# 4대 핵심과제 추진
# ∙ 학교단위 체육활동 확대
# ∙ 학생 맞춤형 체력향상 지원
# ∙ 체육활동 일상화 및 관련 인프라 확충
# ∙ 늘봄학교 프로그램에 체육활동 강화
# 학생 중심
# 건강서비스 확대
# ∙ 건강 수준 진단 내실화 및 증진활동 강화
# ∙ 정신건강 취약 학생 보호 강화
# ∙ 건강취약 우려 학생에 대한 밀착지원
# ∙ 주요 질환·질병 예방관리 강화
# 건강한
# 교육환경 조성
# ∙ 학교시설의 유해물질 관리 강화
# ∙ 학교주변 위험요인 관리 강화
# ∙ 건강한 식생활 환경 조성
# 건강교육 활성화
# 및 지원체계 강화
# ∙ 성장·발달단계 기반 교육지원 내실화
# ∙ 가정·지역사회 연계 건강교육 활성화
# ∙ 범부처 및 유관기관 간 협력체계 강화
# ∙ 지역사회 인·물적 인프라 구축 및 확대
# 방향
# 학교 및 지역사회 중심의 통합적 지원체계 마련
# 건강한 학생, 미래의 행복과 희망
# 비전

# %% [markdown]
# ### pdf 파일 표 읽어오기 -> 일시 중단 (인코딩 에러)

# %%
#pdf 인코딩 살펴보기
import chardet

with open(path, "rb") as f:
    result = chardet.detect(f.readline())
    print(result["encoding"])
# Out:
# IBM866

# %%
import tabula
dfs = tabula.read_pdf(path, pages="all", encoding='IBM866')
len(dfs)
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# Cell In[10], line 2
#       1 import tabula
# ----> 2 dfs = tabula.read_pdf(path, pages="all", encoding='IBM866')
#       3 len(dfs)
#
# File ~/anaconda3/lib/python3.11/site-packages/tabula/io.py:395, in read_pdf(input_path, output_format, encoding, java_options, pandas_options, multiple_tables, user_agent, use_raw_url, pages, guess, area, relative_area, lattice, stream, password, silent, columns, relative_columns, format, batch, output_path, force_subprocess, options)
#     392     raise ValueError(f"{path} is empty. Check the file, or download it manually.")
#     394 try:
# --> 395     output = _run(
#     396         tabula_options,
#     397         java_options,
#     398         path,
#     399         encoding=encoding,
#     400         force_subprocess=force_subprocess,
#     401     )
#     402 finally:
#     403     if temporary:
#
# File ~/anaconda3/lib/python3.11/site-packages/tabula/io.py:82, in _run(options, java_options, path, encoding, force_subprocess)
#      79 elif set(java_options) - IGNORED_JAVA_OPTIONS:
#      80     logger.warning("java_options is ignored until rebooting the Python process.")
# ---> 82 return _tabula_vm.call_tabula_java(options, path)
#
# File ~/anaconda3/lib/python3.11/site-packages/tabula/backend.py:116, in SubprocessTabula.call_tabula_java(self, options, path)
#     108     result = subprocess.run(
#     109         args,
#     110         stdout=subprocess.PIPE,
#    (...)
#     113         check=True,
#     114     )
#     115     if result.stderr:
# --> 116         logger.warning(f"Got stderr: {result.stderr.decode(self.encoding)}")
#     117     return result.stdout.decode(self.encoding)
#     118 except FileNotFoundError:
#
# UnicodeDecodeError: 'cp949' codec can't decode byte 0xec in position 1: illegal multibyte sequence

# %% [markdown]
# ### 단어 빈도분석

# %%
pip install nltk
# Out:
# Requirement already satisfied: nltk in /Users/inda/anaconda3/lib/python3.11/site-packages (3.8.1)
# Requirement already satisfied: click in /Users/inda/anaconda3/lib/python3.11/site-packages (from nltk) (8.0.4)
# Requirement already satisfied: joblib in /Users/inda/anaconda3/lib/python3.11/site-packages (from nltk) (1.2.0)
# Requirement already satisfied: regex>=2021.8.3 in /Users/inda/anaconda3/lib/python3.11/site-packages (from nltk) (2022.7.9)
# Requirement already satisfied: tqdm in /Users/inda/anaconda3/lib/python3.11/site-packages (from nltk) (4.65.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install --upgrade pip
# Out:
# Requirement already satisfied: pip in /Users/inda/anaconda3/lib/python3.11/site-packages (24.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install konlpy
# Out:
# Collecting konlpy
#   Downloading konlpy-0.6.0-py2.py3-none-any.whl.metadata (1.9 kB)
# Requirement already satisfied: JPype1>=0.7.0 in /Users/inda/anaconda3/lib/python3.11/site-packages (from konlpy) (1.5.0)
# Requirement already satisfied: lxml>=4.1.0 in /Users/inda/anaconda3/lib/python3.11/site-packages (from konlpy) (4.9.3)
# Requirement already satisfied: numpy>=1.6 in /Users/inda/anaconda3/lib/python3.11/site-packages (from konlpy) (1.24.3)
# Requirement already satisfied: packaging in /Users/inda/anaconda3/lib/python3.11/site-packages (from JPype1>=0.7.0->konlpy) (23.1)
# Downloading konlpy-0.6.0-py2.py3-none-any.whl (19.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.4/19.4 MB 4.9 MB/s eta 0:00:0000:0100:01
# Installing collected packages: konlpy
# Successfully installed konlpy-0.6.0
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install wordcloud
# Out:
# Collecting wordcloud
#   Downloading wordcloud-1.9.3-cp311-cp311-macosx_11_0_arm64.whl.metadata (3.4 kB)
# Requirement already satisfied: numpy>=1.6.1 in /Users/inda/anaconda3/lib/python3.11/site-packages (from wordcloud) (1.24.3)
# Requirement already satisfied: pillow in /Users/inda/anaconda3/lib/python3.11/site-packages (from wordcloud) (10.0.1)
# Requirement already satisfied: matplotlib in /Users/inda/anaconda3/lib/python3.11/site-packages (from wordcloud) (3.7.2)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/inda/anaconda3/lib/python3.11/site-packages (from matplotlib->wordcloud) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in /Users/inda/anaconda3/lib/python3.11/site-packages (from matplotlib->wordcloud) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/inda/anaconda3/lib/python3.11/site-packages (from matplotlib->wordcloud) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/inda/anaconda3/lib/python3.11/site-packages (from matplotlib->wordcloud) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /Users/inda/anaconda3/lib/python3.11/site-packages (from matplotlib->wordcloud) (23.1)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in /Users/inda/anaconda3/lib/python3.11/site-packages (from matplotlib->wordcloud) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/inda/anaconda3/lib/python3.11/site-packages (from matplotlib->wordcloud) (2.8.2)
# Requirement already satisfied: six>=1.5 in /Users/inda/anaconda3/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.16.0)
# Downloading wordcloud-1.9.3-cp311-cp311-macosx_11_0_arm64.whl (168 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 168.3/168.3 kB 4.0 MB/s eta 0:00:00a 0:00:01
# Installing collected packages: wordcloud
# Successfully installed wordcloud-1.9.3
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install --upgrade gensim
# Out:
# Requirement already satisfied: gensim in /Users/inda/anaconda3/lib/python3.11/site-packages (4.3.0)
# Collecting gensim
#   Downloading gensim-4.3.2-cp311-cp311-macosx_11_0_arm64.whl.metadata (8.3 kB)
# Requirement already satisfied: numpy>=1.18.5 in /Users/inda/anaconda3/lib/python3.11/site-packages (from gensim) (1.24.3)
# Requirement already satisfied: scipy>=1.7.0 in /Users/inda/anaconda3/lib/python3.11/site-packages (from gensim) (1.11.1)
# Requirement already satisfied: smart-open>=1.8.1 in /Users/inda/anaconda3/lib/python3.11/site-packages (from gensim) (5.2.1)
# Downloading gensim-4.3.2-cp311-cp311-macosx_11_0_arm64.whl (24.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.0/24.0 MB 3.7 MB/s eta 0:00:0000:0100:01
# Installing collected packages: gensim
#   Attempting uninstall: gensim
#     Found existing installation: gensim 4.3.0
#     Uninstalling gensim-4.3.0:
#       Successfully uninstalled gensim-4.3.0
# Successfully installed gensim-4.3.2
# Note: you may need to restart the kernel to use updated packages.

# %%
from konlpy.tag import Kkma
kkma = Kkma()
import nltk

# %%
# 전문 읽기
from konlpy.corpus import kobill
doc_ko = open('./231228_김현숙_여성가족부_장관_2024년_신년사_최종배포본.txt').read()
doc_ko
# Out:
# '- 1 -\n※ 보도일시 : 2023.12.29.(금) 오후 15시 이후\n2024년 김현숙 여성가족부장관 신년사\n안녕하십니까. 푸른 용의 해, 갑진년 새해가 밝았습니다. 힘찬 기세로 \n상승하는 용의 움직임처럼 목표를 향해 거침없이 전진하고, 뜻하신 일 \n모두 결실을 이루시는 한해 보내시길 바랍니다.  \n2023년 한해 여성가족부는 ‘누구 하나 소외되지 않는 가족, 모두가 \n함께하는 사회 구현’ 등 국정과제 이행에 속도를 높이고자 노력하였\n습니다. 홀로 아이를 키우는 한부모, 일과 육아를 병행하는 맞벌이, \n기댈 곳 없이 위기에 서 있는 청소년, 폭력 피해로 어려움에 직면해 \n있는 피해자 등 소외되는 사람 없이 모두가 혜택을 누릴 수 있도록 \n세심하게 살피면서, 부족한 부분은 지자체, 학교, 기업 등 다양한 \n기관들과 협력하며 채우고자 하였습니다.\n먼저 저소득 한부모가족 아동양육비 지원과 아이돌봄서비스 지원을 \n확대하고 긴급‧단시간 아이돌봄서비스를 시범운영하여 공적돌봄\n체계를 튼튼히 했습니다. 코로나19 이후 악화된 청소년의 마음건강을 \n돌보기 위해 고위기 청소년 집중 심리 클리닉을 운영하고, 기업과 힘을 \n합쳐 청소년 마음건강지킴이 버스를 운행하여 찾아가는 전문상담을 \n지원했습니다. 또한, 학교와 청소년 시설 간 유기적 연계를 위해 여성\n가족부와 각 지자체 및 교육청, 지역 청소년기관이 함께하는 ‘청정동행’ \n업무협약으로 청소년들에게 더 많은 체험, 활동 기회를 제공했습니다.\n새일센터 직업교육훈련 프로그램에 인공지능, 반도체 기초설계, 바이오‧\n헬스 등 유망 일자리 분야 훈련 과정을 시범 도입하여, 새일센터가 \n경력단절여성 취업 지원 기관이자, 신기술 분야 인재양성기관으로 성장할 \n수 있는 발판을 놓았습니다. 또한 폭력 피해자 보호를 두텁게 하기 \n위해 스토킹방지법을 제정․시행하고, 긴급주거지원 서비스 등 스토킹\n- 2 -\n피해자 지원체계를 새롭게 구축하는 한편, 스토킹을 동반한 디지털\n성범죄 같이 복합적인 피해를 입은 분들이 개별 기관에 찾아다니며 일상\n회복이 지연되지 않도록 ‘통합해결책(솔루션) 지원단’을 설치‧운영했습\n니다. \n2024년 새해 여성가족부는 청소년‧청년의 건강한 성장과 자립지원, \n약자복지 강화, 저출산 대응 세 가지 업무에 정책 역량을 집중하고자 \n합니다. \n첫째, 청소년의 성장 파트너가 되겠습니다. \n청소년들의 미래를 위협하는 유해환경으로부터 높고 튼튼한 벽을 세우겠습\n니다. 자살‧자해 위험이 있는 고위기청소년 발굴 체계를 온‧오프라인으로 \n다양화하고, ‘고위기청소년 집중심리클리닉’ 전담인력을 100명 이상 신규 \n충원하여 청소년 마음건강을 돌보겠습니다. ‘사이버 도박’ 문제 진단 대상을 \n확대하여 도박‧마약류 등 유해환경으로부터 청소년 보호를 강화하겠습\n니다. 청소년기에 시작된 고립‧은둔이 성인기까지 이어지지 않도록 고립\n‧은둔 청소년의 발굴부터 자립‧취업까지 지원하는 ‘고립‧은둔 통합(원\n스톱) 패키지’를 신설‧운영하겠습니다. \n언어발달, 기초학습 지원, 진로설계 역량 강화 등 다문화 아동‧청소년의 \n성장단계에 맞는 맞춤형 지원을 강화하겠습니다. 특히, 학령기 다문화 \n청소년이 증가함에 따라 학교 및 지역 교육청과 협력해 공동의 과제를 \n발굴하고, 추진해나가겠습니다.  \n본격적인 사회 진출에 앞서 더 많은 경험과 도전의 기회를 가질 수 \n있도록 학령기‧후기청소년들을 위한 진로탐색 프로그램을 확대하고, \n사회적 지원이 부족했던 자립지원관 퇴소 청소년들을 위한 자립지원\n수당을 신설합니다.\n- 3 -\n둘째, 약자복지를 통한 민생안정입니다. \n한부모가족 양육비 지원대상을 넓혀 더 많은 가족들의 생활안정을 지원\n하고, 비양육부모가 자녀와의 원만한 관계를 이어가며 양육 책임도 다할 \n수 있도록 면접교섭 서비스 운영을 전국 가족센터로 확대합니다. 긴급\n돌봄, 위기지원, 생활서비스 등 가족유형별 맞춤형 지원을 강화하여 \n도움이 필요한 가족을 적시에 지원하겠습니다.\n폭력 피해자 지원체계를 더 촘촘히 하겠습니다. 스토킹 피해자 긴급주거\n지원 서비스 지역을 전국 17개 시‧도로 넓혀 필요한 분들이 더 가까이에서 \n도움을 받을 수 있도록 지원하고, ‘통합해결책(솔루션) 지원단’ 운영 지\n역도 확대합니다. \n이제 아홉 분밖에 남지 않은 일본군‘위안부’ 피해 할머니들께서 편안한 \n노후를 보내실 수 있도록 세심히 살피는 한편, 할머니들의 명예와 존엄 \n회복을 위한 노력도 지속해 나가겠습니다. \n셋째, 인구위기에 맞서 저출산 대응에 전력을 다하겠습니다. \n이제 남녀 모두 일하는 사회입니다. ‘함께 일하고, 함께 돌보는 사회’를 \n위해 내년부터 2자녀 이상 다자녀를 키우는 맞벌이 가정에 아이돌봄\n서비스 이용금액을 추가 지원하여 양육부담을 낮춰드리겠습니다. 정부지원 \n아이돌봄서비스 이용가구를 8.5만 가구에서 11만 가구까지 크게 늘리겠습\n니다. \n일‧가정 양립을 지원하는 기업의 서포터가 되겠습니다. 근로자의 일‧가정 \n양립에 모범이 되는 가족친화인증 기업에 실질적 도움이 되는 인센티브를 \n새롭게 발굴하겠습니다. 인사제도‧조직 전문가들이 기업 특성에 맞는 일‧\n가정 양립, 조직 다양성 확보 방안을 분석, 제안하는 컨설팅 프로그램을 \n- 4 -\n운영하여 기업의 부담을 나눠 들겠습니다.   \n저출산에 따른 생산가능인구 감소는 이미 시작됐고, 노동력 부족은 경제\n전체의 활력 저하로 이어집니다. 국제통화기금(IMF)은 최근 한국 경제의 \n역동성을 더하기 위한 확실한 해법으로 여성들의 경제활동 참여 촉진, \n노동시장 내 성별격차 완화를 제시했습니다. 여성가족부는 경력단절\n여성들이 IT, 바이오 등 고부가가치 산업에 진출할 수 있도록 적극 \n지원하고, 새일센터 직업교육훈련이 지역의 핵심 산업과 밀착해 운영될 \n수 있도록 기업, 지자체와 협력을 강화해나가겠습니다. \n새해를 앞둔 지금 대내외 여건이 만만치 않습니다. 안타깝게도 위기는 \n사회의 가장 약한 고리부터 찾아가기 마련입니다. 위기‧취약가족, \n폭력 피해자, 위기청소년 등 사회적 약자 곁에 있어야 하는 여성가족부 \n장관으로서 어느 때보다 더 각별한 각오로 국민 여러분의 삶을 살피\n겠습니다.\n우리 삶의 모든 순간을 함께하고, 힘들 때 가장 먼저 떠올리는 존재는  \n‘가족’입니다. 2024년에는 세상 모든 이들이 따뜻하게 기댈 수 있는 \n‘안식처’, 힘이 되어 줄 수 있는 ‘언제나 든든한 가족’으로 여성가족부가 \n거듭날 수 있도록 더욱 노력하겠습니다.\n새해 복 많이 받으십시오. \n감사합니다. \n2023년 12월 29일 \n여성가족부 장관 김현숙\n'

# %%
# 단어 뽑아내기
from konlpy.tag import Okt; t = Okt()
tokens_ko = t.nouns(doc_ko)
tokens_ko
# Out:
# ['보도',
#  '일시',
#  '금',
#  '오후',
#  '이후',
#  '김현숙',
#  '여성가족부',
#  '장관',
#  '신년사',
#  '안녕하십니까',
#  '푸른',
#  '용의',
#  '해',
#  '갑진년',
#  '새해',
#  '기세',
#  '상승',
#  '용의',
#  '움직임',
#  '목표',
#  '향',
#  '전진',
#  '뜻',
#  '일',
#  '모두',
#  '결실',
#  '한해',
#  '한해',
#  '여성가족부',
#  '누구',
#  '하나',
#  '소외',
#  '가족',
#  '모두',
#  '사회',
#  '구현',
#  '등',
#  '국정',
#  '과제',
#  '이행',
#  '속도',
#  '노력',
#  '홀로',
#  '아이',
#  '한부모',
#  '일과',
#  '육아',
#  '병행',
#  '맞벌이',
#  '곳',
#  '위기',
#  '청소년',
#  '폭력',
#  '피해',
#  '어려움',
#  '직면',
#  '피해자',
#  '등',
#  '소외',
#  '사람',
#  '모두',
#  '혜택',
#  '수',
#  '세심',
#  '부분',
#  '지자체',
#  '학교',
#  '기업',
#  '등',
#  '기관',
#  '협력',
#  '먼저',
#  '소득',
#  '한부모',
#  '가족',
#  '아동',
#  '양육비',
#  '지원',
#  '아이돌',
#  '봄',
#  '서비스',
#  '지원',
#  '확대',
#  '긴급',
#  '단시간',
#  '아이',
#  '서비스',
#  '시범',
#  '운영',
#  '공적',
#  '체계',
#  '코로나',
#  '이후',
#  '악화',
#  '청소년',
#  '마음',
#  '건강',
#  '위해',
#  '위기',
#  '청소년',
#  '집중',
#  '심리',
#  '클리',
#  '닉',
#  '운영',
#  '기업',
#  '힘',
#  '청소년',
#  '마음',
#  '건강',
#  '지킴',
#  '버스',
#  '운행',
#  '상담',
#  '지원',
#  '또한',
#  '학교',
#  '청소년',
#  '시설',
#  '간',
#  '유기',
#  '계',
#  '위해',
#  '여성',
#  '가족부',
#  '각',
#  '지자체',
#  '및',
#  '교육청',
#  '지역',
#  '청소년',
#  '기관',
#  '청정',
#  '동행',
#  '업무',
#  '협약',
#  '청소년',
#  '더',
#  '체험',
#  '활동',
#  '기회',
#  '제공',
#  '센터',
#  '직업',
#  '교육',
#  '훈련',
#  '프로그램',
#  '인공',
#  '지능',
#  '반도체',
#  '기초',
#  '설계',
#  '바이오',
#  '헬스',
#  '등',
#  '유망',
#  '일자리',
#  '분야',
#  '훈련',
#  '과정',
#  '시범',
#  '도입',
#  '센터',
#  '경력',
#  '단절',
#  '여성',
#  '취업',
#  '지원',
#  '기관',
#  '이자',
#  '기술',
#  '분야',
#  '인재',
#  '기관',
#  '수',
#  '발판',
#  '또한',
#  '폭력',
#  '피해자',
#  '보호',
#  '위해',
#  '스토킹',
#  '방지법',
#  '제정',
#  '시행',
#  '긴급',
#  '주거지',
#  '서비스',
#  '등',
#  '스토킹',
#  '피해자',
#  '체계',
#  '구축',
#  '한편',
#  '스토킹',
#  '동반',
#  '디지털',
#  '성범죄',
#  '복합',
#  '피해',
#  '분',
#  '개별',
#  '기관',
#  '일상',
#  '회복',
#  '지연',
#  '통합',
#  '해결',
#  '책',
#  '솔루션',
#  '원단',
#  '설치',
#  '운영',
#  '습',
#  '새해',
#  '여성가족부',
#  '청소년',
#  '청년',
#  '성장',
#  '자립',
#  '지원',
#  '약자',
#  '복지',
#  '강화',
#  '저출산',
#  '대응',
#  '세',
#  '가지',
#  '업무',
#  '정책',
#  '역량',
#  '집중',
#  '첫째',
#  '청소년',
#  '성장',
#  '파트너',
#  '청소년',
#  '미래',
#  '위협',
#  '유해',
#  '환경',
#  '벽',
#  '습',
#  '자살',
#  '자해',
#  '위험',
#  '위기',
#  '청소년',
#  '발굴',
#  '체계',
#  '온',
#  '오프라인',
#  '다양',
#  '위기',
#  '청소년',
#  '집중',
#  '심리',
#  '클리',
#  '닉',
#  '전담',
#  '인력',
#  '명',
#  '이상',
#  '신규',
#  '충',
#  '청소년',
#  '마음',
#  '건강',
#  '사이버',
#  '도박',
#  '문제',
#  '진단',
#  '대상',
#  '확대',
#  '도박',
#  '마약',
#  '류',
#  '등',
#  '유해',
#  '환경',
#  '청소년',
#  '보호',
#  '습',
#  '청소년기',
#  '시작',
#  '고립',
#  '은둔',
#  '성인기',
#  '고립',
#  '은둔',
#  '청소년',
#  '발굴',
#  '자립',
#  '취업',
#  '지원',
#  '고립',
#  '은둔',
#  '통합',
#  '원',
#  '스톱',
#  '패키지',
#  '를',
#  '신설',
#  '운영',
#  '언어',
#  '발달',
#  '기초',
#  '학습',
#  '지원',
#  '진로',
#  '설계',
#  '역량',
#  '강화',
#  '등',
#  '다문화',
#  '아동',
#  '청소년',
#  '장단',
#  '맞춤',
#  '지원',
#  '학령기',
#  '다문화',
#  '청소년',
#  '증가',
#  '함',
#  '학교',
#  '및',
#  '지역',
#  '교육청',
#  '협력',
#  '공동',
#  '과제',
#  '발굴',
#  '추진',
#  '본격',
#  '사회',
#  '진출',
#  '앞서',
#  '더',
#  '경험',
#  '도전',
#  '기회',
#  '수',
#  '학령기',
#  '후기',
#  '청소년',
#  '위',
#  '진로',
#  '탐색',
#  '프로그램',
#  '확대',
#  '사회',
#  '지원이',
#  '자립',
#  '지원',
#  '관',
#  '퇴소',
#  '청소년',
#  '위',
#  '자립',
#  '지원',
#  '수당',
#  '신설',
#  '둘째',
#  '약자',
#  '복지',
#  '통한',
#  '민생',
#  '안정',
#  '한부모',
#  '가족',
#  '양육비',
#  '대상',
#  '더',
#  '가족',
#  '생활',
#  '안정',
#  '지원',
#  '비양',
#  '부모',
#  '자녀',
#  '관계',
#  '어가',
#  '양육',
#  '책임',
#  '수',
#  '면접',
#  '교섭',
#  '서비스',
#  '운영',
#  '전국',
#  '가족',
#  '센터',
#  '확대',
#  '긴급',
#  '위기',
#  '지원',
#  '생활',
#  '서비스',
#  '등',
#  '가족',
#  '유형',
#  '별',
#  '맞춤',
#  '지원',
#  '도움',
#  '가족',
#  '지원',
#  '폭력',
#  '피해자',
#  '체계',
#  '더',
#  '스토킹',
#  '피해자',
#  '긴급',
#  '주거',
#  '지원',
#  '서비스',
#  '지역',
#  '전국',
#  '개',
#  '시',
#  '도로',
#  '분',
#  '더',
#  '가까이',
#  '도움',
#  '수',
#  '지원',
#  '통합',
#  '해결',
#  '책',
#  '솔루션',
#  '원단',
#  '운영',
#  '역도',
#  '확대',
#  '이제',
#  '아홉',
#  '분',
#  '남지',
#  '일본군',
#  '위안부',
#  '피해',
#  '할머니',
#  '노후',
#  '수',
#  '세',
#  '한편',
#  '할머니',
#  '명예',
#  '존엄',
#  '회복',
#  '위',
#  '노력',
#  '지속',
#  '인구',
#  '위기',
#  '저출산',
#  '대응',
#  '전력',
#  '이제',
#  '남녀',
#  '모두',
#  '일',
#  '사회',
#  '일',
#  '사회',
#  '를',
#  '위해',
#  '내년',
#  '자녀',
#  '이상',
#  '자녀',
#  '맞벌이',
#  '가정',
#  '아이돌',
#  '봄',
#  '서비스',
#  '이용',
#  '금액',
#  '추가',
#  '지원',
#  '부담',
#  '정부',
#  '지원',
#  '아이돌',
#  '봄',
#  '서비스',
#  '이용',
#  '가구',
#  '가구',
#  '가구',
#  '크게',
#  '습',
#  '일',
#  '가정',
#  '양립',
#  '지원',
#  '기업',
#  '서포터',
#  '근로자',
#  '일',
#  '가정',
#  '양립',
#  '모범',
#  '가족',
#  '친',
#  '인증',
#  '기업',
#  '실질',
#  '도움',
#  '인센티브',
#  '발굴',
#  '인사',
#  '제도',
#  '조직',
#  '전문가',
#  '기업',
#  '특성',
#  '일',
#  '가정',
#  '양립',
#  '조직',
#  '다양성',
#  '확보',
#  '방안',
#  '분석',
#  '제안',
#  '컨설팅',
#  '프로그램',
#  '운영',
#  '기업',
#  '부담',
#  '저출산',
#  '생산',
#  '가능',
#  '인구',
#  '감소',
#  '시작',
#  '노동',
#  '부족',
#  '경제',
#  '전체',
#  '활',
#  '저하',
#  '국제통화기금',
#  '은',
#  '최근',
#  '한국',
#  '경제',
#  '역',
#  '동성',
#  '더하기',
#  '위',
#  '해법',
#  '여성',
#  '경제활동',
#  '참여',
#  '촉진',
#  '노동시장',
#  '내',
#  '성별',
#  '격차',
#  '완화',
#  '제시',
#  '여성가족부',
#  '경력',
#  '단절',
#  '여성',
#  '바이오',
#  '등',
#  '부가가치',
#  '산업',
#  '진출',
#  '수',
#  '적극',
#  '지원',
#  '센터',
#  '직업',
#  '교육',
#  '훈련',
#  '지역',
#  '핵심',
#  '산업',
#  '밀착',
#  '운영',
#  '수',
#  '기업',
#  '지자체',
#  '협력',
#  '새해',
#  '지금',
#  '내외',
#  '여건',
#  '만',
#  '위기',
#  '사회',
#  '가장',
#  '고리',
#  '마련',
#  '위기',
#  '취약',
#  '가족',
#  '폭력',
#  '피해자',
#  '위기',
#  '청소년',
#  '등',
#  '사회',
#  '약자',
#  '곁',
#  '여성가족부',
#  '장관',
#  '때',
#  '더',
#  '각별',
#  '각오',
#  '국민',
#  '여러분',
#  '삶',
#  '살피',
#  '우리',
#  '삶',
#  '모든',
#  '순간',
#  '때',
#  '가장',
#  '먼저',
#  '존재',
#  '가족',
#  '세상',
#  '모든',
#  '이',
#  '수',
#  '안식처',
#  '힘',
#  '줄',
#  '수',
#  '가족',
#  '여성가족부',
#  '거듭',
#  '날',
#  '수',
#  '더욱',
#  '노력',
#  '새해',
#  '복',
#  '여성가족부',
#  '장관',
#  '김현숙']

# %%
# 단어 세기 - 명사만 추출
ko = nltk.Text(tokens_ko)
print(len(ko.tokens)) #단어 총 개수세기
print(len(set(ko.tokens))) #단어 유니크 개수 세기
ko.vocab()
# Out:
# 651
# 357
# FreqDist({'청소년': 20, '지원': 20, '가족': 11, '수': 11, '등': 10, '위기': 9, '서비스': 8, '운영': 8, '여성가족부': 7, '사회': 7, ...})

# %% [markdown]
# ### 시각화해서 빈도 보기

# %%
import matplotlib.pyplot as plt
from matplotlib import font_manager, rc
rc('font', family='AppleGothic')
plt.rcParams['axes.unicode_minus'] = False

# %%
# 단어 별 개수 시각화
plt.figure()
ko.plot(30)
plt.show()

# %% [markdown]
# #### 필요 없는 단어 제거

# %%
#필요 없는 단어 제거

#학생/청소년 관련 자료 정제
# stop_words = ['청소년','지원','및','등','시','제','운영','사업', '경우','참여','위원회','법',
#              '수','이상','명','비','신청', '편', '실적', '평가', '관', '담당',
#              '가능','대상','계','내','도','위','내용','구','발급','프로그램','위원',
#              '함','학교','교육','학생']

#여가부 신년사 정제 - 불필요한 단어만
stop_words = ['수','등','세','를','더','분','닉','습','위','또한','뜻']

ko = [each_word for each_word in ko if each_word not in stop_words]
ko
# Out:
# ['보도',
#  '일시',
#  '금',
#  '오후',
#  '이후',
#  '김현숙',
#  '여성가족부',
#  '장관',
#  '신년사',
#  '안녕하십니까',
#  '푸른',
#  '용의',
#  '해',
#  '갑진년',
#  '새해',
#  '기세',
#  '상승',
#  '용의',
#  '움직임',
#  '목표',
#  '향',
#  '전진',
#  '일',
#  '모두',
#  '결실',
#  '한해',
#  '한해',
#  '여성가족부',
#  '누구',
#  '하나',
#  '소외',
#  '가족',
#  '모두',
#  '사회',
#  '구현',
#  '국정',
#  '과제',
#  '이행',
#  '속도',
#  '노력',
#  '홀로',
#  '아이',
#  '한부모',
#  '일과',
#  '육아',
#  '병행',
#  '맞벌이',
#  '곳',
#  '위기',
#  '청소년',
#  '폭력',
#  '피해',
#  '어려움',
#  '직면',
#  '피해자',
#  '소외',
#  '사람',
#  '모두',
#  '혜택',
#  '세심',
#  '부분',
#  '지자체',
#  '학교',
#  '기업',
#  '기관',
#  '협력',
#  '먼저',
#  '소득',
#  '한부모',
#  '가족',
#  '아동',
#  '양육비',
#  '지원',
#  '아이돌',
#  '봄',
#  '서비스',
#  '지원',
#  '확대',
#  '긴급',
#  '단시간',
#  '아이',
#  '서비스',
#  '시범',
#  '운영',
#  '공적',
#  '체계',
#  '코로나',
#  '이후',
#  '악화',
#  '청소년',
#  '마음',
#  '건강',
#  '위해',
#  '위기',
#  '청소년',
#  '집중',
#  '심리',
#  '클리',
#  '운영',
#  '기업',
#  '힘',
#  '청소년',
#  '마음',
#  '건강',
#  '지킴',
#  '버스',
#  '운행',
#  '상담',
#  '지원',
#  '학교',
#  '청소년',
#  '시설',
#  '간',
#  '유기',
#  '계',
#  '위해',
#  '여성',
#  '가족부',
#  '각',
#  '지자체',
#  '및',
#  '교육청',
#  '지역',
#  '청소년',
#  '기관',
#  '청정',
#  '동행',
#  '업무',
#  '협약',
#  '청소년',
#  '체험',
#  '활동',
#  '기회',
#  '제공',
#  '센터',
#  '직업',
#  '교육',
#  '훈련',
#  '프로그램',
#  '인공',
#  '지능',
#  '반도체',
#  '기초',
#  '설계',
#  '바이오',
#  '헬스',
#  '유망',
#  '일자리',
#  '분야',
#  '훈련',
#  '과정',
#  '시범',
#  '도입',
#  '센터',
#  '경력',
#  '단절',
#  '여성',
#  '취업',
#  '지원',
#  '기관',
#  '이자',
#  '기술',
#  '분야',
#  '인재',
#  '기관',
#  '발판',
#  '폭력',
#  '피해자',
#  '보호',
#  '위해',
#  '스토킹',
#  '방지법',
#  '제정',
#  '시행',
#  '긴급',
#  '주거지',
#  '서비스',
#  '스토킹',
#  '피해자',
#  '체계',
#  '구축',
#  '한편',
#  '스토킹',
#  '동반',
#  '디지털',
#  '성범죄',
#  '복합',
#  '피해',
#  '개별',
#  '기관',
#  '일상',
#  '회복',
#  '지연',
#  '통합',
#  '해결',
#  '책',
#  '솔루션',
#  '원단',
#  '설치',
#  '운영',
#  '새해',
#  '여성가족부',
#  '청소년',
#  '청년',
#  '성장',
#  '자립',
#  '지원',
#  '약자',
#  '복지',
#  '강화',
#  '저출산',
#  '대응',
#  '가지',
#  '업무',
#  '정책',
#  '역량',
#  '집중',
#  '첫째',
#  '청소년',
#  '성장',
#  '파트너',
#  '청소년',
#  '미래',
#  '위협',
#  '유해',
#  '환경',
#  '벽',
#  '자살',
#  '자해',
#  '위험',
#  '위기',
#  '청소년',
#  '발굴',
#  '체계',
#  '온',
#  '오프라인',
#  '다양',
#  '위기',
#  '청소년',
#  '집중',
#  '심리',
#  '클리',
#  '전담',
#  '인력',
#  '명',
#  '이상',
#  '신규',
#  '충',
#  '청소년',
#  '마음',
#  '건강',
#  '사이버',
#  '도박',
#  '문제',
#  '진단',
#  '대상',
#  '확대',
#  '도박',
#  '마약',
#  '류',
#  '유해',
#  '환경',
#  '청소년',
#  '보호',
#  '청소년기',
#  '시작',
#  '고립',
#  '은둔',
#  '성인기',
#  '고립',
#  '은둔',
#  '청소년',
#  '발굴',
#  '자립',
#  '취업',
#  '지원',
#  '고립',
#  '은둔',
#  '통합',
#  '원',
#  '스톱',
#  '패키지',
#  '신설',
#  '운영',
#  '언어',
#  '발달',
#  '기초',
#  '학습',
#  '지원',
#  '진로',
#  '설계',
#  '역량',
#  '강화',
#  '다문화',
#  '아동',
#  '청소년',
#  '장단',
#  '맞춤',
#  '지원',
#  '학령기',
#  '다문화',
#  '청소년',
#  '증가',
#  '함',
#  '학교',
#  '및',
#  '지역',
#  '교육청',
#  '협력',
#  '공동',
#  '과제',
#  '발굴',
#  '추진',
#  '본격',
#  '사회',
#  '진출',
#  '앞서',
#  '경험',
#  '도전',
#  '기회',
#  '학령기',
#  '후기',
#  '청소년',
#  '진로',
#  '탐색',
#  '프로그램',
#  '확대',
#  '사회',
#  '지원이',
#  '자립',
#  '지원',
#  '관',
#  '퇴소',
#  '청소년',
#  '자립',
#  '지원',
#  '수당',
#  '신설',
#  '둘째',
#  '약자',
#  '복지',
#  '통한',
#  '민생',
#  '안정',
#  '한부모',
#  '가족',
#  '양육비',
#  '대상',
#  '가족',
#  '생활',
#  '안정',
#  '지원',
#  '비양',
#  '부모',
#  '자녀',
#  '관계',
#  '어가',
#  '양육',
#  '책임',
#  '면접',
#  '교섭',
#  '서비스',
#  '운영',
#  '전국',
#  '가족',
#  '센터',
#  '확대',
#  '긴급',
#  '위기',
#  '지원',
#  '생활',
#  '서비스',
#  '가족',
#  '유형',
#  '별',
#  '맞춤',
#  '지원',
#  '도움',
#  '가족',
#  '지원',
#  '폭력',
#  '피해자',
#  '체계',
#  '스토킹',
#  '피해자',
#  '긴급',
#  '주거',
#  '지원',
#  '서비스',
#  '지역',
#  '전국',
#  '개',
#  '시',
#  '도로',
#  '가까이',
#  '도움',
#  '지원',
#  '통합',
#  '해결',
#  '책',
#  '솔루션',
#  '원단',
#  '운영',
#  '역도',
#  '확대',
#  '이제',
#  '아홉',
#  '남지',
#  '일본군',
#  '위안부',
#  '피해',
#  '할머니',
#  '노후',
#  '한편',
#  '할머니',
#  '명예',
#  '존엄',
#  '회복',
#  '노력',
#  '지속',
#  '인구',
#  '위기',
#  '저출산',
#  '대응',
#  '전력',
#  '이제',
#  '남녀',
#  '모두',
#  '일',
#  '사회',
#  '일',
#  '사회',
#  '위해',
#  '내년',
#  '자녀',
#  '이상',
#  '자녀',
#  '맞벌이',
#  '가정',
#  '아이돌',
#  '봄',
#  '서비스',
#  '이용',
#  '금액',
#  '추가',
#  '지원',
#  '부담',
#  '정부',
#  '지원',
#  '아이돌',
#  '봄',
#  '서비스',
#  '이용',
#  '가구',
#  '가구',
#  '가구',
#  '크게',
#  '일',
#  '가정',
#  '양립',
#  '지원',
#  '기업',
#  '서포터',
#  '근로자',
#  '일',
#  '가정',
#  '양립',
#  '모범',
#  '가족',
#  '친',
#  '인증',
#  '기업',
#  '실질',
#  '도움',
#  '인센티브',
#  '발굴',
#  '인사',
#  '제도',
#  '조직',
#  '전문가',
#  '기업',
#  '특성',
#  '일',
#  '가정',
#  '양립',
#  '조직',
#  '다양성',
#  '확보',
#  '방안',
#  '분석',
#  '제안',
#  '컨설팅',
#  '프로그램',
#  '운영',
#  '기업',
#  '부담',
#  '저출산',
#  '생산',
#  '가능',
#  '인구',
#  '감소',
#  '시작',
#  '노동',
#  '부족',
#  '경제',
#  '전체',
#  '활',
#  '저하',
#  '국제통화기금',
#  '은',
#  '최근',
#  '한국',
#  '경제',
#  '역',
#  '동성',
#  '더하기',
#  '해법',
#  '여성',
#  '경제활동',
#  '참여',
#  '촉진',
#  '노동시장',
#  '내',
#  '성별',
#  '격차',
#  '완화',
#  '제시',
#  '여성가족부',
#  '경력',
#  '단절',
#  '여성',
#  '바이오',
#  '부가가치',
#  '산업',
#  '진출',
#  '적극',
#  '지원',
#  '센터',
#  '직업',
#  '교육',
#  '훈련',
#  '지역',
#  '핵심',
#  '산업',
#  '밀착',
#  '운영',
#  '기업',
#  '지자체',
#  '협력',
#  '새해',
#  '지금',
#  '내외',
#  '여건',
#  '만',
#  '위기',
#  '사회',
#  '가장',
#  '고리',
#  '마련',
#  '위기',
#  '취약',
#  '가족',
#  '폭력',
#  '피해자',
#  '위기',
#  '청소년',
#  '사회',
#  '약자',
#  '곁',
#  '여성가족부',
#  '장관',
#  '때',
#  '각별',
#  '각오',
#  '국민',
#  '여러분',
#  '삶',
#  '살피',
#  '우리',
#  '삶',
#  '모든',
#  '순간',
#  '때',
#  '가장',
#  '먼저',
#  '존재',
#  '가족',
#  '세상',
#  '모든',
#  '이',
#  '안식처',
#  '힘',
#  '줄',
#  '가족',
#  '여성가족부',
#  '거듭',
#  '날',
#  '더욱',
#  '노력',
#  '새해',
#  '복',
#  '여성가족부',
#  '장관',
#  '김현숙']

# %%
# 리스트를 nltk.Text 객체로 변환
ko_edited = nltk.Text(ko, name='여가부 신년사')

# 시각화
plt.figure(figsize=(12,6))
ko_edited.plot(30)
plt.show()

# %%
from wordcloud import WordCloud, STOPWORDS

data = ko_edited.vocab().most_common(150)
wordcloud = WordCloud(font_path = './NanumBarunGothic.ttf',
                      background_color='white', 
                      colormap = 'Accent_r', 
                      width = 800,
                      height = 800).generate_from_frequencies(dict(data))

plt.figure(figsize=(12,8))
plt.imshow(wordcloud)
plt.axis('off')
plt.show()

# %% [markdown]
# ### 컬럼 제목 언급 수 찾기

# %%
ko.count('수면')
# Out:
# 0

# %%
# # 텍스트 파일에서 단어 개수 세는 함수 정의
# def count_words(file_path, target_words):
#     word_counts = {word: 0 for word in target_words}  # 각 단어의 등장 횟수를 저장할 딕셔너리 초기화

#     # 텍스트 파일 열고 단어 개수 세기
#     with open(file_path, 'r', encoding='utf-8') as file:
#         for line in file:
#             words = line.split()  # 공백을 기준으로 단어들을 분리
#             for word in words:
#                 # 각 단어가 등장할 때마다 카운트를 증가시킴
#                 if word in target_words:
#                     word_counts[word] += 1

#     return word_counts

# # 텍스트 파일 경로
# file_path = './(1권) 2024년 청소년사업 안내_1.30.txt'  # 텍스트 파일의 경로를 적절히 수정해주세요.

# # 찾고자 하는 단어들
# target_words = ['신체활동','비만','흡연','음주','식생활','구강','위생','아토피','천식',
#                '약물','인터넷','중독','수면','음주','자살','스트레스','외로움','불안',
#                '행복','학교폭력','성폭력','유해업소','사행','대출','보호자','교사','친구',
#                '기관','센터','성교육','안전']  # 실제 찾고자 하는 단어들로 변경해주세요.

# # 단어 개수 세기
# word_counts = count_words(file_path, target_words)

# # 결과 출력
# for word, count in word_counts.items():
#     print(f'"{word}"의 등장 횟수: {count}')

--> 오류! ~을, ~를 등 붙은 단어를 찾아내지 못함. 첫 번째 KoNLPy의 Okt 형태소 분석기 활용
# Out:
# "신체활동"의 등장 횟수: 0
# "비만"의 등장 횟수: 0
# "흡연"의 등장 횟수: 0
# "음주"의 등장 횟수: 0
# "식생활"의 등장 횟수: 0
# "구강"의 등장 횟수: 0
# "위생"의 등장 횟수: 3
# "아토피"의 등장 횟수: 0
# "천식"의 등장 횟수: 0
# "약물"의 등장 횟수: 2
# "인터넷"의 등장 횟수: 6
# "중독"의 등장 횟수: 3
# "수면"의 등장 횟수: 0
# "자살"의 등장 횟수: 2
# "스트레스"의 등장 횟수: 0
# "외로움"의 등장 횟수: 0
# "불안"의 등장 횟수: 0
# "행복"의 등장 횟수: 1
# "학교폭력"의 등장 횟수: 2
# "성폭력"의 등장 횟수: 2
# "유해업소"의 등장 횟수: 0
# "사행"의 등장 횟수: 0
# "대출"의 등장 횟수: 0
# "보호자"의 등장 횟수: 21
# "교사"의 등장 횟수: 2
# "친구"의 등장 횟수: 0
# "기관"의 등장 횟수: 40
# "센터"의 등장 횟수: 29
# "성교육"의 등장 횟수: 1
# "안전"의 등장 횟수: 10

# %% [markdown]
# #### 컬럼 별 중심단어 찾기

# %%
from collections import Counter

def count_specific_words(text, specific_words):
    # Okt 형태소 분석기 초기화
    okt = Okt()
    # 명사만 추출
    nouns = okt.nouns(text)
    # Counter 객체를 사용하여 각 단어의 빈도를 세기
    word_counter = Counter(nouns)
    # 각 단어의 빈도를 저장할 딕셔너리 초기화
    word_counts = {word: word_counter[word] for word in specific_words}
    return word_counts

# 텍스트 파일 경로
# file_path = './(1권) 2024년 청소년사업 안내_1.30.txt' 
# file_path = './(2권) 2024년 청소년사업 안내_1.30.txt'
# file_path = './2024년+학생건강증진+분야+주요업무+추진방향.txt'
# file_path = './2023년 학생건강증진 분야 주요업무 추진방향 230111.txt'
# file_path = './231228_김현숙_여성가족부_장관_2024년_신년사_최종배포본.txt' -> 청소년 국한 발표가 아니라 무의미
file_path = "./[3.28.목.행사시작(14시)이후] 2023년 학생 건강검사 표본통계 및 청소년건강행태조사 결과 발표 (1).txt"


# 찾고자 하는 단어들
target_words = ['신체활동','운동','비만','흡연','음주','식생활','구강','위생','아토피','천식',
               '약물','인터넷','중독','수면','우울','자살','스트레스','외로움','불안',
               '행복','학교폭력','성폭력','유해업소','사행','대출','보호자','교사','친구',
               '기관','센터','성교육','안전']  

# 텍스트 파일 읽기
with open(file_path, 'r', encoding='utf-8') as file:
    text = file.read()

# 특정 단어들의 개수 세기
word_counts = count_specific_words(text, target_words)

# 결과 출력
for word, count in word_counts.items():
    print(f'"{word}"의 등장 횟수: {count}')
# Out:
# "신체활동"의 등장 횟수: 0
# "운동"의 등장 횟수: 1
# "비만"의 등장 횟수: 18
# "흡연"의 등장 횟수: 8
# "음주"의 등장 횟수: 13
# "식생활"의 등장 횟수: 8
# "구강"의 등장 횟수: 3
# "위생"의 등장 횟수: 1
# "아토피"의 등장 횟수: 2
# "천식"의 등장 횟수: 2
# "약물"의 등장 횟수: 2
# "인터넷"의 등장 횟수: 3
# "중독"의 등장 횟수: 2
# "수면"의 등장 횟수: 1
# "우울"의 등장 횟수: 1
# "자살"의 등장 횟수: 0
# "스트레스"의 등장 횟수: 4
# "외로움"의 등장 횟수: 0
# "불안"의 등장 횟수: 0
# "행복"의 등장 횟수: 1
# "학교폭력"의 등장 횟수: 0
# "성폭력"의 등장 횟수: 0
# "유해업소"의 등장 횟수: 0
# "사행"의 등장 횟수: 0
# "대출"의 등장 횟수: 0
# "보호자"의 등장 횟수: 0
# "교사"의 등장 횟수: 1
# "친구"의 등장 횟수: 0
# "기관"의 등장 횟수: 4
# "센터"의 등장 횟수: 1
# "성교육"의 등장 횟수: 0
# "안전"의 등장 횟수: 1
